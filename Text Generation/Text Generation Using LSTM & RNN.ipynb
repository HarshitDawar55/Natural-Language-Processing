# %% [markdown]
# # Text Generation using LSTM & RNN by `Mr. Harshit Dawar!`

# %%
# Importing the Required Libraries
import spacy
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# Function to print read the data from a file
def read_Data(path):
    with open(path, "r") as p:
        text = p.read()
    return text

# %%
read_Data("data.txt")
# Out:
# 'Call me Ishmael.  Some years ago--never mind how long\nprecisely--having little or no money in my purse, and nothing\nparticular to interest me on shore, I thought I would sail about a\nlittle and see the watery part of the world.  It is a way I have of\ndriving off the spleen and regulating the circulation.  Whenever I\nfind myself growing grim about the mouth; whenever it is a damp,\ndrizzly November in my soul; whenever I find myself involuntarily\npausing before coffin warehouses, and bringing up the rear of every\nfuneral I meet; and especially whenever my hypos get such an upper\nhand of me, that it requires a strong moral principle to prevent me\nfrom deliberately stepping into the street, and methodically knocking\npeople\'s hats off--then, I account it high time to get to sea as soon\nas I can.  This is my substitute for pistol and ball.  With a\nphilosophical flourish Cato throws himself upon his sword; I quietly\ntake to the ship.  There is nothing surprising in this.  If they but\nknew it, almost all men in their degree, some time or other, cherish\nvery nearly the same feelings towards the ocean with me.\n\nThere now is your insular city of the Manhattoes, belted round by\nwharves as Indian isles by coral reefs--commerce surrounds it with\nher surf.  Right and left, the streets take you waterward.  Its\nextreme downtown is the battery, where that noble mole is washed by\nwaves, and cooled by breezes, which a few hours previous were out of\nsight of land.  Look at the crowds of water-gazers there.\n\nCircumambulate the city of a dreamy Sabbath afternoon.  Go from\nCorlears Hook to Coenties Slip, and from thence, by Whitehall,\nnorthward.  What do you see?--Posted like silent sentinels all around\nthe town, stand thousands upon thousands of mortal men fixed in ocean\nreveries.  Some leaning against the spiles; some seated upon the\npier-heads; some looking over the bulwarks of ships from China; some\nhigh aloft in the rigging, as if striving to get a still better\nseaward peep.  But these are all landsmen; of week days pent up in\nlath and plaster--tied to counters, nailed to benches, clinched to\ndesks.  How then is this?  Are the green fields gone?  What do they\nhere?\n\nBut look! here come more crowds, pacing straight for the water, and\nseemingly bound for a dive.  Strange!  Nothing will content them but\nthe extremest limit of the land; loitering under the shady lee of\nyonder warehouses will not suffice.  No.  They must get just as nigh\nthe water as they possibly can without falling in.  And there they\nstand--miles of them--leagues.  Inlanders all, they come from lanes\nand alleys, streets and avenues--north, east, south, and west.  Yet\nhere they all unite.  Tell me, does the magnetic virtue of the\nneedles of the compasses of all those ships attract them thither?\n\nOnce more.  Say you are in the country; in some high land of lakes.\nTake almost any path you please, and ten to one it carries you down\nin a dale, and leaves you there by a pool in the stream.  There is\nmagic in it.  Let the most absent-minded of men be plunged in his\ndeepest reveries--stand that man on his legs, set his feet a-going,\nand he will infallibly lead you to water, if water there be in all\nthat region.  Should you ever be athirst in the great American\ndesert, try this experiment, if your caravan happen to be supplied\nwith a metaphysical professor.  Yes, as every one knows, meditation\nand water are wedded for ever.\n\nBut here is an artist.  He desires to paint you the dreamiest,\nshadiest, quietest, most enchanting bit of romantic landscape in all\nthe valley of the Saco.  What is the chief element he employs?  There\nstand his trees, each with a hollow trunk, as if a hermit and a\ncrucifix were within; and here sleeps his meadow, and there sleep his\ncattle; and up from yonder cottage goes a sleepy smoke.  Deep into\ndistant woodlands winds a mazy way, reaching to overlapping spurs of\nmountains bathed in their hill-side  ...

# %%
# Downloading the package for the Spacy English Language
# !python -m spacy download en_core_web_sm

# %%
# Creating a SpaCy Model for English
ENGLISH_MODEL_NLP = spacy.load("en_core_web_sm", disable = ["ner", "tagger", "parser"])

# %%
ENGLISH_MODEL_NLP.pipe_names
# Out:
# ['tok2vec', 'attribute_ruler', 'lemmatizer']

# %%
# Setting the Max Length to a bigger number to use the complete dataset.
ENGLISH_MODEL_NLP.max_length = 1250000

# %%
# Function to remove the punctuations from the dataset
def remove_punc(data):
    return [token.text.lower() for token in ENGLISH_MODEL_NLP(data) if not token.is_punct
            and not token.text in "\n \n\n '"]

# %%
# Generating tokens from the data
tokens = remove_punc(read_Data("data.txt"))

# %%
len(tokens)
# Out:
# 11328

# %%
tokens[:5]
# Out:
# ['call', 'me', 'ishmael', 'some', 'years']

# %%
# Generating sequences of 15 words to predict the 16th word in the sentence
sequences = []
sequence_length = 15

for i in range(len(tokens) - sequence_length):
    sequences.append(tokens[i : i + sequence_length])

# %%
# Total length is 15 less than the actual length of the Tokens list because of the Sequence Length to be 15.
len(sequences)
# Out:
# 11313

# %%
len(sequences[0])
# Out:
# 15

# %%
" ".join(sequences[0])
# Out:
# 'call me ishmael some years ago never mind how long precisely having little or no'

# %% [markdown]
# ## Converting the Sequences into the Numerical Form that a Model Understands/Accepts

# %%
from keras.preprocessing.text import Tokenizer
import numpy as np

# %%
text_tokenizer = Tokenizer()
text_tokenizer.fit_on_texts(sequences)

# %%
# tokenized_sequences = text_tokenizer.texts_to_matrix(sequences)

# %%
# np.unique(tokenized_sequences[0])

# %%
tokenized_sequences = text_tokenizer.texts_to_sequences(sequences)

# %%
tokenized_sequences[0]
# Out:
# [956, 14, 262, 51, 260, 407, 87, 218, 129, 111, 954, 259, 50, 43, 37]

# %%
# Printing the word and their corresponding numbers
text_tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'a',
#  3: 'and',
#  4: 'of',
#  5: 'i',
#  6: 'to',
#  7: 'in',
#  8: 'it',
#  9: 'that',
#  10: 'he',
#  11: 'his',
#  12: 'was',
#  13: 'but',
#  14: 'me',
#  15: 'with',
#  16: 'as',
#  17: 'at',
#  18: 'this',
#  19: 'you',
#  20: 'is',
#  21: 'all',
#  22: 'for',
#  23: 'my',
#  24: 'on',
#  25: 'be',
#  26: "'s",
#  27: 'not',
#  28: 'from',
#  29: 'there',
#  30: 'one',
#  31: 'up',
#  32: 'what',
#  33: 'him',
#  34: 'so',
#  35: 'bed',
#  36: 'now',
#  37: 'no',
#  38: 'about',
#  39: 'into',
#  40: 'by',
#  41: 'were',
#  42: 'out',
#  43: 'or',
#  44: 'harpooneer',
#  45: 'had',
#  46: 'then',
#  47: 'have',
#  48: 'an',
#  49: 'upon',
#  50: 'little',
#  51: 'some',
#  52: 'old',
#  53: 'like',
#  54: 'if',
#  55: 'they',
#  56: 'would',
#  57: 'do',
#  58: 'over',
#  59: 'landlord',
#  60: 'thought',
#  61: 'room',
#  62: 'when',
#  63: 'could',
#  64: "n't",
#  65: 'night',
#  66: 'here',
#  67: 'head',
#  68: 'such',
#  69: 'which',
#  70: 'man',
#  71: 'did',
#  72: 'sea',
#  73: 'time',
#  74: 'other',
#  75: 'very',
#  76: 'go',
#  77: 'these',
#  78: 'more',
#  79: 'though',
#  80: 'first',
#  81: 'sort',
#  82: 'said',
#  83: 'last',
#  84: 'down',
#  85: 'most',
#  86: 'been',
#  87: 'never',
#  88: 'your',
#  89: 'them',
#  90: 'must',
#  91: 'tell',
#  92: 'much',
#  93: 'good',
#  94: 'see',
#  95: 'off',
#  96: 'myself',
#  97: 'are',
#  98: 'yet',
#  99: 'sleep',
#  100: 'who',
#  101: 'seemed',
#  102: 'light',
#  103: 'way',
#  104: 'their',
#  105: 'just',
#  106: 'being',
#  107: 'than',
#  108: 'place',
#  109: 'queequeg',
#  110: 'great',
#  111: 'long',
#  112: 'before',
#  113: 'get',
#  114: 'round',
#  115: 'where',
#  116: 'still',
#  117: 'any',
#  118: 'too',
#  119: 'only',
#  120: 'door',
#  121: 'can',
#  122: 'himself',
#  123: 'heads',
#  124: 'come',
#  125: 'ever',
#  126: 'two',
#  127: 'enough',
#  128: 'made',
#  129: 'how',
#  130: 'hand',
#  131: 'same',
#  132: 'looking',
#  133: 'something',
#  134: 'may',
#  135: 'nothing',
#  136: 'almost',
#  137: 'say',
#  138: 'should',
#  139: 'side',
#  140: 'why',
#  141: 'own',
#  142: 'we',
#  143: 'new',
#  144: 'again',
#  145: 'came',
#  146: 'arm',
#  147: 'house',
#  148: 'away',
#  149: 'might',
#  150: 'take',
#  151: 'towards',
#  152: 'will',
#  153: 'under',
#  154: 'going',
#  155: 'make',
#  156: 'whale',
#  157: 'stood',
#  158: 'boots',
#  159: 'ye',
#  160: 'back',
#  161: "'ll",
#  162: 'tomahawk',
#  163: 'part',
#  164: 'world',
#  165: 'soon',
#  166: 'water',
#  167: 'against',
#  168: 'those',
#  169: 'between',
#  170: 'after',
#  171: 'whaling',
#  172: 'lay',
#  173: 'took',
#  174: 'half',
#  175: 'began',
#  176: 'face',
#  177: 'streets',
#  178: 'land',
#  179: 'better',
#  180: 'once',
#  181: 'voyage',
#  182: 'give',
#  183: 'rather',
#  184: 'well',
#  185: 'however',
#  186: 'else',
#  187: 'heard',
#  188: 'put',
#  189: 'stop',
#  190: 'dark',
#  191: 'went',
#  192: 'black',
#  193: 'window',
#  194: 'cannibal',
#  195: 'fire',
#  196: 'every',
#  197: 'ship',
#  198: 'stand',
#  199: 'strange',
#  200: 'without',
#  201: 'feet',
#  202: 'whether',
#  203: 'because',
#  204: 'eyes',
#  205: 'think',
#  206: 'thinks',
#  207: 'idea',
#  208: 'bag',
#  209: 'nantucket',
#  210: 'late',
#  211: 'cold',
#  212: 'our',
#  213: 'found',
#  214: 'full',
#  215: 'morning',
#  216: 'sleeping',
#  217: 'got',
#  218: 'mind',
#  219: 'particular',
#  220: 'her',
#  221: 'right',
#  222: 'its',
#  223: 'look',
#  224: 'town',
#  225: 'south',
#  226: 'does',
#  227: 'let',
#  228: 'set',
#  229: 'yourself',
#  230: 'image',
#  231: 'saw',
#  232: 'am',
#  233: 'besides',
#  234: 'sailor',
#  235: 'seas',
#  236: 'rolled',
#  237: 'till',
#  238: 'day',
#  239: 'sign',
#  240: 'looked',
#  241: 'hard',
#  242: 'moment',
#  243: 'corner',
#  244: 'entry',
#  245: 'four',
#  246: 'wall',
#  247: 'savage',
#  248: 'table',
#  249: 'indeed',
#  250: 'bench',
#  251: 'chest',
#  252: 'while',
#  253: 'stranger',
#  254: 'possible',
#  255: 'feeling',
#  256: 'floor',
#  257: 'squares',
#  258: 'hat',
#  259: 'having',
#  260: 'years',
#  261: 'harpoon',
#  262: 'ishmael',
#  263: 'money',
#  264: 'whenever',
#  265: 'mouth',
#  266: 'high',
#  267: 'knew',
#  268: 'men',
#  269: 'hours',
#  270: 'green',
#  271: 'bit',
#  272: 'within',
#  273: 'picture',
#  274: 'told',
#  275: 'story',
#  276: 'mean',
#  277: 'speak',
#  278: 'order',
#  279: 'making',
#  280: 'even',
#  281: 'perhaps',
#  282: 'things',
#  283: 'answer',
#  284: 'parts',
#  285: 'wild',
#  286: 'reason',
#  287: 'young',
#  288: 'craft',
#  289: 'business',
#  290: 'dead',
#  291: 'another',
#  292: 'middle',
#  293: 'sure',
#  294: 'candle',
#  295: 'presently',
#  296: 'low',
#  297: 'turned',
#  298: 'teeth',
#  299: 'dim',
#  300: 'euroclydon',
#  301: 'kept',
#  302: 'glass',
#  303: 'afterwards',
#  304: 'large',
#  305: 'three',
#  306: 'telling',
#  307: 'getting',
#  308: 'small',
#  309: 'next',
#  310: 'seeing',
#  311: 'sell',
#  312: 'felt',
#  313: 'sun',
#  314: 'sail',
#  315: 'coffin',
#  316: 'especially',
#  317: 'street',
#  318: 'city',
#  319: 'few',
#  320: 'previous',
#  321: 'sight',
#  322: 'days',
#  323: 'straight',
#  324: 'nigh',
#  325: 'legs',
#  326: 'try',
#  327: 'yes',
#  328: 'unless',
#  329: 'poor',
#  330: 'coat',
#  331: 'passenger',
#  332: 'taking',
#  333: 'true',
#  334: 'thing',
#  335: 'ai',
#  336: 'always',
#  337: 'us',
#  338: 'really',
#  339: 'marvellous',
#  340: 'heaven',
#  341: 'air',
#  342: 'far',
#  343: 'second',
#  344: 'many',
#  345: 'has',
#  346: 'unaccountable',
#  347: 'grand',
#  348: 'jolly',
#  349: 'open',
#  350: 'shirt',
#  351: 'cape',
#  352: 'bedford',
#  353: 'fine',
#  354: 'further',
#  355: 'ice',
#  356: 'frost',
#  357: 'foot',
#  358: 'wide',
#  359: 'white',
#  360: 'tall',
#  361: 'i.',
#  362: 'wooden',
#  363: 'worse',
#  364: 'death',
#  365: 'mine',
#  366: 'lazarus',
#  367: 'keep',
#  368: 'along',
#  369: 'hung',
#  370: 'throwing',
#  371: 'centre',
#  372: 'rest',
#  373: 'fact',
#  374: 'hair',
#  375: 'broken',
#  376: 'kill',
#  377: 'through',
#  378: 'chimney',
#  379: 'fancy',
#  380: 'bar',
#  381: 'trying',
#  382: 'dumplings',
#  383: 'heavens',
#  384: 'manner',
#  385: 'devil',
#  386: 'together',
#  387: 'seen',
#  388: 'deal',
#  389: 'know',
#  390: 'skin',
#  391: 'ca',
#  392: 'shavings',
#  393: 'peddling',
#  394: 'sunday',
#  395: 'counterpane',
#  396: 'mat',
#  397: 'christian',
#  398: 'commenced',
#  399: 'thinking',
#  400: 'similar',
#  401: 'afraid',
#  402: 'length',
#  403: 'idol',
#  404: 'e',
#  405: 'sabbee',
#  406: 'waking',
#  407: 'ago',
#  408: 'purse',
#  409: 'find',
#  410: 'damp',
#  411: 'soul',
#  412: 'strong',
#  413: 'account',
#  414: 'sword',
#  415: 'quietly',
#  416: 'degree',
#  417: 'left',
#  418: 'around',
#  419: 'fixed',
#  420: 'ships',
#  421: 'miles',
#  422: 'country',
#  423: 'stream',
#  424: 'lead',
#  425: 'american',
#  426: 'artist',
#  427: 'each',
#  428: 'goes',
#  429: 'deep',
#  430: 'distant',
#  431: 'winds',
#  432: 'blue',
#  433: 'among',
#  434: 'suddenly',
#  435: 'feel',
#  436: 'meaning',
#  437: 'phantom',
#  438: 'life',
#  439: 'passengers',
#  440: 'nor',
#  441: 'kind',
#  442: 'quite',
#  443: 'care',
#  444: 'board',
#  445: 'somehow',
#  446: 'broiled',
#  447: 'mast',
#  448: 'sense',
#  449: 'knowing',
#  450: 'either',
#  451: 'passed',
#  452: 'hands',
#  453: 'paying',
#  454: 'pay',
#  455: 'penny',
#  456: 'sailors',
#  457: 'exactly',
#  458: 'short',
#  459: 'easy',
#  460: 'portentous',
#  461: 'island',
#  462: 'nameless',
#  463: 'sounds',
#  464: 'since',
#  465: 'snow',
#  466: 'saturday',
#  467: 'matter',
#  468: 'red',
#  469: 'partly',
#  470: 'ere',
#  471: 'became',
#  472: 'meanwhile',
#  473: 'pocket',
#  474: 'darkness',
#  475: 'fish',
#  476: 'inn',
#  477: 'watch',
#  478: 'broad',
#  479: 'entering',
#  480: 'ha',
#  481: 'ashes',
#  482: 'opened',
#  483: 'spouter',
#  484: 'name',
#  485: 'suppose',
#  486: 'quiet',
#  487: 'best',
#  488: 'tempestuous',
#  489: 'says',
#  490: 'thou',
#  491: 'both',
#  492: 'occurred',
#  493: 'dives',
#  494: 'holding',
#  495: 'frozen',
#  496: 'altogether',
#  497: 'plain',
#  498: 'whom',
#  499: 'clean',
#  500: 'human',
#  501: 'entered',
#  502: 'wrinkled',
#  503: 'shelf',
#  504: 'jonah',
#  505: 'blanket',
#  506: "goin'",
#  507: 'bitter',
#  508: 'supper',
#  509: 'sat',
#  510: 'settle',
#  511: 'chap',
#  512: 'help',
#  513: 'spend',
#  514: 'landed',
#  515: 'standing',
#  516: 'held',
#  517: 'somewhat',
#  518: 'sober',
#  519: 'whole',
#  520: 'dam',
#  521: 'brown',
#  522: 'bulkington',
#  523: "o'clock",
#  524: 'none',
#  525: 'coming',
#  526: "'ve",
#  527: 'wait',
#  528: 'plane',
#  529: 'saying',
#  530: 'grinning',
#  531: 'placed',
#  532: 'shouted',
#  533: 'bedfellow',
#  534: 'zealand',
#  535: 'sal',
#  536: 'wash',
#  537: 'thrown',
#  538: 'purplish',
#  539: 'turn',
#  540: 'completely',
#  541: 'fear',
#  542: 'grego',
#  543: 'baby',
#  544: 'slowly',
#  545: 'civilized',
#  546: 'monkey',
#  547: 'involuntarily',
#  548: 'pausing',
#  549: 'warehouses',
#  550: 'requires',
#  551: 'people',
#  552: 'nearly',
#  553: 'ocean',
#  554: 'indian',
#  555: 'waterward',
#  556: 'battery',
#  557: 'noble',
#  558: 'washed',
#  559: 'crowds',
#  560: 'sabbath',
#  561: 'afternoon',
#  562: 'thence',
#  563: 'silent',
#  564: 'thousands',
#  565: 'reveries',
#  566: 'leaning',
#  567: 'seated',
#  568: 'bulwarks',
#  569: 'aloft',
#  570: 'week',
#  571: 'plaster',
#  572: 'gone',
#  573: 'bound',
#  574: 'content',
#  575: 'yonder',
#  576: 'falling',
#  577: 'north',
#  578: 'please',
#  579: 'ten',
#  580: 'leaves',
#  581: 'magic',
#  582: 'plunged',
#  583: 'metaphysical',
#  584: 'chief',
#  585: 'trunk',
#  586: 'meadow',
#  587: 'smoke',
#  588: 'reaching',
#  589: 'hill',
#  590: 'thus',
#  591: 'pine',
#  592: 'sighs',
#  593: 'shepherd',
#  594: 'june',
#  595: 'scores',
#  596: 'thousand',
#  597: 'sadly',
#  598: 'robust',
#  599: 'healthy',
#  600: 'boy',
#  601: 'crazy',
#  602: 'hold',
#  603: 'holy',
#  604: 'brother',
#  605: 'ourselves',
#  606: 'begin',
#  607: 'grow',
#  608: 'inferred',
#  609: 'needs',
#  610: "don't",
#  611: 'themselves',
#  612: 'commodore',
#  613: 'captain',
#  614: 'cook',
#  615: 'glory',
#  616: 'whatsoever',
#  617: 'confess',
#  618: 'officer',
#  619: 'respectfully',
#  620: 'horse',
#  621: 'huge',
#  622: 'houses',
#  623: 'forecastle',
#  624: 'jump',
#  625: 'spar',
#  626: 'particularly',
#  627: 'putting',
#  628: 'tar',
#  629: 'schoolmaster',
#  630: 'boys',
#  631: 'transition',
#  632: 'grin',
#  633: 'bear',
#  634: 'hunks',
#  635: 'sweep',
#  636: 'weighed',
#  637: 'anything',
#  638: 'less',
#  639: 'thump',
#  640: 'point',
#  641: 'view',
#  642: 'single',
#  643: 'difference',
#  644: 'act',
#  645: 'uncomfortable',
#  646: 'compare',
#  647: 'earthly',
#  648: 'enter',
#  649: 'deck',
#  650: 'quarter',
#  651: 'leaders',
#  652: 'smelt',
#  653: 'fates',
#  654: 'doubtless',
#  655: 'formed',
#  656: 'run',
#  657: '\n\n\n',
#  658: 'stage',
#  659: 'shabby',
#  660: 'others',
#  661: 'circumstances',
#  662: 'motives',
#  663: 'various',
#  664: 'mysterious',
#  665: 'curiosity',
#  666: 'tormented',
#  667: 'everlasting',
#  668: 'wonder',
#  669: 'purpose',
#  670: 'floated',
#  671: 'stuffed',
#  672: 'horn',
#  673: 'arrived',
#  674: 'offer',
#  675: 'following',
#  676: 'embark',
#  677: 'pleased',
#  678: 'original',
#  679: 'stranded',
#  680: 'leviathan',
#  681: 'whales',
#  682: 'nay',
#  683: 'dismal',
#  684: 'wherever',
#  685: 'dreary',
#  686: 'crossed',
#  687: 'expensive',
#  688: 'bright',
#  689: 'windows',
#  690: 'packed',
#  691: 'inches',
#  692: 'thick',
#  693: 'hear',
#  694: 'tinkling',
#  695: 'glasses',
#  696: 'blackness',
#  697: 'moving',
#  698: 'hour',
#  699: 'proved',
#  700: 'meant',
#  701: 'public',
#  702: 'box',
#  703: 'flying',
#  704: 'harpoons',
#  705: 'trap',
#  706: 'loud',
#  707: 'voice',
#  708: 'sitting',
#  709: 'beyond',
#  710: 'negro',
#  711: 'creaking',
#  712: 'swinging',
#  713: 'painting',
#  714: 'representing',
#  715: 'connexion',
#  716: 'peter',
#  717: 'itself',
#  718: 'carted',
#  719: 'burnt',
#  720: 'spot',
#  721: 'queer',
#  722: 'gable',
#  723: 'ended',
#  724: 'sharp',
#  725: 'wind',
#  726: 'howling',
#  727: 'nevertheless',
#  728: 'called',
#  729: 'outside',
#  730: 'passage',
#  731: 'body',
#  732: 'curbstone',
#  733: 'corn',
#  734: 'pooh',
#  735: 'northern',
#  736: 'lights',
#  737: 'summer',
#  738: 'lengthwise',
#  739: 'gods',
#  740: 'lie',
#  741: 'plenty',
#  742: 'study',
#  743: 'series',
#  744: 'arrive',
#  745: 'shadows',
#  746: 'dint',
#  747: 'conclusion',
#  748: 'confounded',
#  749: 'limber',
#  750: 'truly',
#  751: 'drive',
#  752: 'unimaginable',
#  753: 'midnight',
#  754: 'unnatural',
#  755: 'breaking',
#  756: 'design',
#  757: 'opposite',
#  758: 'monstrous',
#  759: 'knots',
#  760: 'vast',
#  761: 'handle',
#  762: 'wondered',
#  763: 'mixed',
#  764: 'deformed',
#  765: 'flung',
#  766: 'iron',
#  767: 'arched',
#  768: 'cut',
#  769: 'times',
#  770: 'beneath',
#  771: 'covered',
#  772: 'gathered',
#  773: 'stands',
#  774: 'rude',
#  775: 'bone',
#  776: 'abominable',
#  777: 'measure',
#  778: 'seamen',
#  779: 'skrimshander',
#  780: 'sought',
#  781: 'added',
#  782: 'forehead',
#  783: 'objections',
#  784: "'d",
#  785: 'used',
#  786: 'depend',
#  787: 'decent',
#  788: 'want',
#  789: 'ready',
#  790: 'working',
#  791: 'space',
#  792: 'lips',
#  793: 'fingers',
#  794: 'fare',
#  795: 'fellow',
#  796: 'nightmare',
#  797: 'nt',
#  798: 'complexioned',
#  799: 'eats',
#  800: "'em",
#  801: 'afore',
#  802: 'resolved',
#  803: 'noise',
#  804: 'offing',
#  805: 'shaggy',
#  806: 'woollen',
#  807: 'stiff',
#  808: 'labrador',
#  809: 'wake',
#  810: 'bad',
#  811: 'mounted',
#  812: 'generally',
#  813: 'shipmates',
#  814: 'become',
#  815: 'height',
#  816: 'seem',
#  817: 'plan',
#  818: 'private',
#  819: 'unknown',
#  820: 'apartment',
#  821: 'hammock',
#  822: 'linen',
#  823: 'home',
#  824: 'hole',
#  825: 'mattress',
#  826: 'planing',
#  827: 'knot',
#  828: 'near',
#  829: 'sake',
#  830: 'chair',
#  831: 'narrow',
#  832: 'leaving',
#  833: 'interval',
#  834: 'met',
#  835: 'inside',
#  836: 'violent',
#  837: 'ones',
#  838: 'comprehension',
#  839: 'bird',
#  840: 'airley',
#  841: 'airth',
#  842: 'engaged',
#  843: 'whittling',
#  844: 'guess',
#  845: 'done',
#  846: 'break',
#  847: 'broke',
#  848: 'understand',
#  849: 'certain',
#  850: 'demand',
#  851: 'selling',
#  852: 'sir',
#  853: 'string',
#  854: 'mystery',
#  855: 'showed',
#  856: 'dangerous',
#  857: 'flukes',
#  858: 'slept',
#  859: 'big',
#  860: 'sam',
#  861: 'lighted',
#  862: 'wo',
#  863: 'stairs',
#  864: 'placing',
#  865: 'double',
#  866: 'eyeing',
#  867: 'belonging',
#  868: 'papered',
#  869: 'parcel',
#  870: 'tried',
#  871: 'satisfactory',
#  872: 'concerning',
#  873: 'edges',
#  874: 'stuck',
#  875: 'gave',
#  876: 'neck',
#  877: 'sleeves',
#  878: 'undressed',
#  879: 'remembering',
#  880: 'jumped',
#  881: 'pantaloons',
#  882: 'blowing',
#  883: 'doze',
#  884: 'pretty',
#  885: 'heavy',
#  886: 'save',
#  887: 'infernal',
#  888: 'peddler',
#  889: 'yellow',
#  890: 'colour',
#  891: 'dreadfully',
#  892: 'sticking',
#  893: 'cheeks',
#  894: 'truth',
#  895: 'remembered',
#  896: 'whaleman',
#  897: 'tattooed',
#  898: 'concluded',
#  899: 'lying',
#  900: 'tanning',
#  901: 'hot',
#  902: 'produced',
#  903: 'beaver',
#  904: 'singing',
#  905: 'bolted',
#  906: 'arms',
#  907: 'running',
#  908: 'curious',
#  909: 'hunch',
#  910: 'congo',
#  911: 'ill',
#  912: 'takes',
#  913: 'biscuit',
#  914: 'top',
#  915: 'lamp',
#  916: 'succeeded',
#  917: 'polite',
#  918: 'guttural',
#  919: 'pagan',
#  920: 'spell',
#  921: 'tobacco',
#  922: 'grunt',
#  923: 'whatever',
#  924: 'ee',
#  925: 'horrid',
#  926: 'pipe',
#  927: 'smoking',
#  928: 'complied',
#  929: 'patchwork',
#  930: 'figure',
#  931: 'shade',
#  932: 'quilt',
#  933: 'hugging',
#  934: 'sensations',
#  935: 'explain',
#  936: 'remember',
#  937: 'circumstance',
#  938: 'reality',
#  939: 'stepmother',
#  940: 'sixteen',
#  941: 'abed',
#  942: 'troubled',
#  943: 'wrapped',
#  944: 'supernatural',
#  945: 'ages',
#  946: 'awful',
#  947: 'consciousness',
#  948: 'observing',
#  949: 'creature',
#  950: 'dress',
#  951: 'watching',
#  952: 'probably',
#  953: 'toilet',
#  954: 'precisely',
#  955: 'jacket',
#  956: 'call',
#  957: 'interest',
#  958: 'shore',
#  959: 'watery',
#  960: 'driving',
#  961: 'spleen',
#  962: 'regulating',
#  963: 'circulation',
#  964: 'growing',
#  965: 'grim',
#  966: 'drizzly',
#  967: 'november',
#  968: 'bringing',
#  969: 'rear',
#  970: 'funeral',
#  971: 'meet',
#  972: 'hypos',
#  973: 'upper',
#  974: 'moral',
#  975: 'principle',
#  976: 'prevent',
#  977: 'deliberately',
#  978: 'stepping',
#  979: 'methodically',
#  980: 'knocking',
#  981: 'hats',
#  982: 'substitute',
#  983: 'pistol',
#  984: 'ball',
#  985: 'philosophical',
#  986: 'flourish',
#  987: 'cato',
#  988: 'throws',
#  989: 'surprising',
#  990: 'cherish',
#  991: 'feelings',
#  992: 'insular',
#  993: 'manhattoes',
#  994: 'belted',
#  995: 'wharves',
#  996: 'isles',
#  997: 'coral',
#  998: 'reefs',
#  999: 'commerce',
#  1000: 'surrounds',
#  ...}

# %%
for word in tokenized_sequences[0]:
    print("{} : {}".format(word, text_tokenizer.index_word[word]))
# Out:
# 956 : call
# 14 : me
# 262 : ishmael
# 51 : some
# 260 : years
# 407 : ago
# 87 : never
# 218 : mind
# 129 : how
# 111 : long
# 954 : precisely
# 259 : having
# 50 : little
# 43 : or
# 37 : no

# %%
# Printing the filters internally used by the Tokenizer for removing the punctuations
text_tokenizer.filters
# Out:
# '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'

# %%
# Printing the word counts in the Data
text_tokenizer.word_counts
# Out:
# OrderedDict([('call', 16),
#              ('me', 1427),
#              ('ishmael', 78),
#              ('some', 439),
#              ('years', 80),
#              ('ago', 51),
#              ('never', 262),
#              ('mind', 98),
#              ('how', 189),
#              ('long', 220),
#              ('precisely', 26),
#              ('having', 87),
#              ('little', 448),
#              ('or', 554),
#              ('no', 585),
#              ('money', 75),
#              ('in', 3269),
#              ('my', 1035),
#              ('purse', 45),
#              ('and', 5573),
#              ('nothing', 165),
#              ('particular', 90),
#              ('to', 3750),
#              ('interest', 15),
#              ('on', 990),
#              ('shore', 15),
#              ('i', 4125),
#              ('thought', 390),
#              ('would', 405),
#              ('sail', 60),
#              ('about', 585),
#              ('a', 5988),
#              ('see', 240),
#              ('the', 8970),
#              ('watery', 15),
#              ('part', 135),
#              ('of', 4785),
#              ('world', 135),
#              ('it', 2445),
#              ('is', 1125),
#              ('way', 225),
#              ('have', 465),
#              ('driving', 15),
#              ('off', 240),
#              ('spleen', 15),
#              ('regulating', 15),
#              ('circulation', 15),
#              ('whenever', 75),
#              ('find', 45),
#              ('myself', 240),
#              ('growing', 15),
#              ('grim', 15),
#              ('mouth', 75),
#              ('damp', 45),
#              ('drizzly', 15),
#              ('november', 15),
#              ('soul', 45),
#              ('involuntarily', 30),
#              ('pausing', 30),
#              ('before', 210),
#              ('coffin', 60),
#              ('warehouses', 30),
#              ('bringing', 15),
#              ('up', 720),
#              ('rear', 15),
#              ('every', 105),
#              ('funeral', 15),
#              ('meet', 15),
#              ('especially', 60),
#              ('hypos', 15),
#              ('get', 210),
#              ('such', 330),
#              ('an', 465),
#              ('upper', 15),
#              ('hand', 180),
#              ('that', 2175),
#              ('requires', 30),
#              ('strong', 45),
#              ('moral', 15),
#              ('principle', 15),
#              ('prevent', 15),
#              ('from', 870),
#              ('deliberately', 15),
#              ('stepping', 15),
#              ('into', 570),
#              ('street', 60),
#              ('methodically', 15),
#              ('knocking', 15),
#              ('people', 30),
#              ("'s", 976),
#              ('hats', 15),
#              ('then', 480),
#              ('account', 45),
#              ('high', 75),
#              ('time', 300),
#              ('sea', 315),
#              ('as', 1365),
#              ('soon', 135),
#              ('can', 195),
#              ('this', 1245),
#              ('substitute', 15),
#              ('for', 1050),
#              ('pistol', 15),
#              ('ball', 15),
#              ('with', 1380),
#              ('philosophical', 15),
#              ('flourish', 15),
#              ('cato', 15),
#              ('throws', 15),
#              ('himself', 195),
#              ('upon', 450),
#              ('his', 1819),
#              ('sword', 45),
#              ('quietly', 45),
#              ('take', 150),
#              ('ship', 105),
#              ('there', 840),
#              ('surprising', 15),
#              ('if', 420),
#              ('they', 420),
#              ('but', 1530),
#              ('knew', 75),
#              ('almost', 165),
#              ('all', 1080),
#              ('men', 75),
#              ('their', 225),
#              ('degree', 45),
#              ('other', 285),
#              ('cherish', 15),
#              ('very', 285),
#              ('nearly', 30),
#              ('same', 180),
#              ('feelings', 15),
#              ('towards', 150),
#              ('ocean', 30),
#              ('now', 600),
#              ('your', 255),
#              ('insular', 15),
#              ('city', 60),
#              ('manhattoes', 15),
#              ('belted', 15),
#              ('round', 210),
#              ('by', 555),
#              ('wharves', 15),
#              ('indian', 30),
#              ('isles', 15),
#              ('coral', 15),
#              ('reefs', 15),
#              ('commerce', 15),
#              ('surrounds', 15),
#              ('her', 90),
#              ('surf', 15),
#              ('right', 90),
#              ('left', 45),
#              ('streets', 120),
#              ('you', 1245),
#              ('waterward', 30),
#              ('its', 90),
#              ('extreme', 15),
#              ('downtown', 15),
#              ('battery', 30),
#              ('where', 210),
#              ('noble', 30),
#              ('mole', 15),
#              ('washed', 30),
#              ('waves', 15),
#              ('cooled', 15),
#              ('breezes', 15),
#              ('which', 330),
#              ('few', 60),
#              ('hours', 75),
#              ('previous', 60),
#              ('were', 555),
#              ('out', 555),
#              ('sight', 60),
#              ('land', 120),
#              ('look', 90),
#              ('at', 1260),
#              ('crowds', 30),
#              ('water', 135),
#              ('gazers', 15),
#              ('circumambulate', 15),
#              ('dreamy', 15),
#              ('sabbath', 30),
#              ('afternoon', 30),
#              ('go', 285),
#              ('corlears', 15),
#              ('hook', 15),
#              ('coenties', 15),
#              ('slip', 15),
#              ('thence', 30),
#              ('whitehall', 15),
#              ('northward', 15),
#              ('what', 645),
#              ('do', 405),
#              ('see?--posted', 15),
#              ('like', 424),
#              ('silent', 30),
#              ('sentinels', 15),
#              ('around', 45),
#              ('town', 90),
#              ('stand', 105),
#              ('thousands', 30),
#              ('mortal', 15),
#              ('fixed', 45),
#              ('reveries', 30),
#              ('leaning', 30),
#              ('against', 135),
#              ('spiles', 15),
#              ('seated', 30),
#              ('pier', 15),
#              ('heads', 195),
#              ('looking', 180),
#              ('over', 405),
#              ('bulwarks', 30),
#              ('ships', 45),
#              ('china', 15),
#              ('aloft', 30),
#              ('rigging', 15),
#              ('striving', 15),
#              ('still', 210),
#              ('better', 120),
#              ('seaward', 15),
#              ('peep', 15),
#              ('these', 285),
#              ('are', 240),
#              ('landsmen', 15),
#              ('week', 30),
#              ('days', 60),
#              ('pent', 15),
#              ('lath', 15),
#              ('plaster', 30),
#              ('tied', 15),
#              ('counters', 15),
#              ('nailed', 15),
#              ('benches', 15),
#              ('clinched', 15),
#              ('desks', 15),
#              ('green', 75),
#              ('fields', 15),
#              ('gone', 30),
#              ('here', 345),
#              ('come', 195),
#              ('more', 285),
#              ('pacing', 15),
#              ('straight', 60),
#              ('seemingly', 15),
#              ('bound', 30),
#              ('dive', 15),
#              ('strange', 105),
#              ('will', 150),
#              ('content', 30),
#              ('them', 255),
#              ('extremest', 15),
#              ('limit', 15),
#              ('loitering', 15),
#              ('under', 150),
#              ('shady', 15),
#              ('lee', 15),
#              ('yonder', 30),
#              ('not', 885),
#              ('suffice', 15),
#              ('must', 255),
#              ('just', 225),
#              ('nigh', 60),
#              ('possibly', 15),
#              ('without', 105),
#              ('falling', 30),
#              ('miles', 45),
#              ('leagues', 15),
#              ('inlanders', 15),
#              ('lanes', 15),
#              ('alleys', 15),
#              ('avenues', 15),
#              ('north', 30),
#              ('east', 15),
#              ('south', 90),
#              ('west', 15),
#              ('yet', 240),
#              ('unite', 15),
#              ('tell', 255),
#              ('does', 90),
#              ('magnetic', 15),
#              ('virtue', 15),
#              ('needles', 15),
#              ('compasses', 15),
#              ('those', 135),
#              ('attract', 15),
#              ('thither', 15),
#              ('once', 120),
#              ('say', 165),
#              ('country', 45),
#              ('lakes', 15),
#              ('any', 210),
#              ('path', 15),
#              ('please', 30),
#              ('ten', 30),
#              ('one', 750),
#              ('carries', 15),
#              ('down', 270),
#              ('dale', 15),
#              ('leaves', 30),
#              ('pool', 15),
#              ('stream', 45),
#              ('magic', 30),
#              ('let', 90),
#              ('most', 270),
#              ('absent', 15),
#              ('minded', 15),
#              ('be', 990),
#              ('plunged', 30),
#              ('deepest', 15),
#              ('man', 330),
#              ('legs', 60),
#              ('set', 90),
#              ('feet', 105),
#              ('going', 150),
#              ('he', 1875),
#              ('infallibly', 15),
#              ('lead', 45),
#              ('region', 15),
#              ('should', 165),
#              ('ever', 195),
#              ('athirst', 15),
#              ('great', 222),
#              ('american', 45),
#              ('desert', 15),
#              ('try', 60),
#              ('experiment', 15),
#              ('caravan', 15),
#              ('happen', 15),
#              ('supplied', 15),
#              ('metaphysical', 30),
#              ('professor', 15),
#              ('yes', 60),
#              ('knows', 15),
#              ('meditation', 15),
#              ('wedded', 15),
#              ('artist', 45),
#              ('desires', 15),
#              ('paint', 15),
#              ('dreamiest', 15),
#              ('shadiest', 15),
#              ('quietest', 15),
#              ('enchanting', 15),
#              ('bit', 75),
#              ('romantic', 15),
#              ('landscape', 15),
#              ('valley', 15),
#              ('saco', 15),
#              ('chief', 30),
#              ('element', 15),
#              ('employs', 15),
#              ('trees', 15),
#              ('each', 45),
#              ('hollow', 15),
#              ('trunk', 30),
#              ('hermit', 15),
#              ('crucifix', 15),
#              ('within', 75),
#              ('sleeps', 15),
#              ('meadow', 30),
#              ('sleep', 240),
#              ('cattle', 15),
#              ('cottage', 15),
#              ('goes', 45),
#              ('sleepy', 15),
#              ('smoke', 30),
#              ('deep', 45),
#              ('distant', 45),
#              ('woodlands', 15),
#              ('winds', 45),
#              ('mazy', 15),
#              ('reaching', 30),
#              ('overlapping', 15),
#              ('spurs', 15),
#              ('mountains', 15),
#              ('bathed', 15),
#              ('hill', 30),
#              ('side', 165),
#              ('blue', 45),
#              ('though', 285),
#              ('picture', 75),
#              ('lies', 15),
#              ('thus', 30),
#              ('tranced', 15),
#              ('pine', 30),
#              ('tree', 15),
#              ('shakes', 15),
#              ('sighs', 30),
#              ('shepherd', 30),
#              ('head', 345),
#              ('vain', 15),
#              ('unless', 60),
#              ('eye', 15),
#              ('him', 630),
#              ('visit', 15),
#              ('prairies', 15),
#              ('june', 30),
#              ('when', 375),
#              ('scores', 30),
#              ('wade', 15),
#              ('knee', 15),
#              ('among', 45),
#              ('tiger', 15),
#              ('lilies', 15),
#              ('charm', 15),
#              ('wanting?--water', 15),
#              ('drop', 15),
#              ('niagara', 15),
#              ('cataract', 15),
#              ('sand', 15),
#              ('travel', 15),
#              ('thousand', 30),
#              ('why', 165),
#              ('did', 330),
#              ('poor', 60),
#              ('poet', 15),
#              ('tennessee', 15),
#              ('suddenly', 45),
#              ('receiving', 15),
#              ('two', 195),
#              ('handfuls', 15),
#              ('silver', 15),
#              ('deliberate', 15),
#              ('whether', 105),
#              ('buy', 15),
#              ('coat', 60),
#              ('sadly', 30),
#              ('needed', 15),
#              ('invest', 15),
#              ('pedestrian', 15),
#              ('trip', 15),
#              ('rockaway', 15),
#              ('beach', 15),
#              ('robust', 30),
#              ('healthy', 30),
#              ('boy', 30),
#              ('crazy', 30),
#              ('first', 285),
#              ('voyage', 120),
#              ('passenger', 60),
#              ('yourself', 90),
#              ('feel', 45),
#              ('mystical', 15),
#              ('vibration', 15),
#              ('told', 75),
#              ('old', 435),
#              ('persians', 15),
#              ('hold', 30),
#              ('holy', 30),
#              ('greeks', 15),
#              ('give', 120),
#              ('separate', 15),
#              ('deity', 15),
#              ('own', 165),
#              ('brother', 30),
#              ('jove', 15),
#              ('surely', 15),
#              ('meaning', 45),
#              ('deeper', 15),
#              ('story', 75),
#              ('narcissus', 15),
#              ('who', 240),
#              ('because', 105),
#              ('could', 375),
#              ('grasp', 15),
#              ('tormenting', 15),
#              ('mild', 15),
#              ('image', 90),
#              ('saw', 90),
#              ('fountain', 15),
#              ('was', 1665),
#              ('drowned', 15),
#              ('we', 165),
#              ('ourselves', 30),
#              ('rivers', 15),
#              ('oceans', 15),
#              ('ungraspable', 15),
#              ('phantom', 45),
#              ('life', 45),
#              ('key', 15),
#              ('am', 90),
#              ('habit', 15),
#              ('begin', 30),
#              ('grow', 30),
#              ('hazy', 15),
#              ('eyes', 105),
#              ('conscious', 15),
#              ('lungs', 15),
#              ('mean', 75),
#              ('inferred', 30),
#              ('needs', 30),
#              ('rag', 15),
#              ('something', 180),
#              ('besides', 90),
#              ('passengers', 45),
#              ('sick', 15),
#              ('quarrelsome', 15),
#              ("don't", 30),
#              ('nights', 15),
#              ('enjoy', 15),
#              ('themselves', 30),
#              ('much', 255),
#              ('general', 15),
#              ('thing;--no', 15),
#              ('nor', 45),
#              ('salt', 15),
#              ('commodore', 30),
#              ('captain', 30),
#              ('cook', 30),
#              ('abandon', 15),
#              ('glory', 30),
#              ('distinction', 15),
#              ('offices', 15),
#              ('abominate', 15),
#              ('honourable', 15),
#              ('respectable', 15),
#              ('toils', 15),
#              ('trials', 15),
#              ('tribulations', 15),
#              ('kind', 45),
#              ('whatsoever', 30),
#              ('quite', 45),
#              ('care', 45),
#              ('taking', 60),
#              ('barques', 15),
#              ('brigs', 15),
#              ('schooners', 15),
#              ('cook,--though', 15),
#              ('confess', 30),
#              ('considerable', 15),
#              ('being', 225),
#              ('sort', 285),
#              ('officer', 30),
#              ('board', 45),
#              ('somehow', 45),
#              ('fancied', 15),
#              ('broiling', 15),
#              ('fowls;--though', 15),
#              ('broiled', 45),
#              ('judiciously', 15),
#              ('buttered', 15),
#              ('judgmatically', 15),
#              ('salted', 15),
#              ('peppered', 15),
#              ('speak', 75),
#              ('respectfully', 30),
#              ('reverentially', 15),
#              ('fowl', 15),
#              ('than', 225),
#              ('idolatrous', 15),
#              ('dotings', 15),
#              ('egyptians', 15),
#              ('ibis', 15),
#              ('roasted', 15),
#              ('river', 15),
#              ('horse', 30),
#              ('mummies', 15),
#              ('creatures', 15),
#              ('huge', 30),
#              ('bake', 15),
#              ('houses', 30),
#              ('pyramids', 15),
#              ('simple', 15),
#              ('sailor', 90),
#              ('mast', 45),
#              ('plumb', 15),
#              ('forecastle', 30),
#              ('royal', 15),
#              ('true', 60),
#              ('rather', 120),
#              ('order', 75),
#              ('make', 150),
#              ('jump', 30),
#              ('spar', 30),
#              ('grasshopper', 15),
#              ('may', 180),
#              ('thing', 60),
#              ('unpleasant', 15),
#              ('enough', 195),
#              ('touches', 15),
#              ('sense', 45),
#              ('honour', 15),
#              ('particularly', 30),
#              ('established', 15),
#              ('family', 15),
#              ('van', 15),
#              ('rensselaers', 15),
#              ('randolphs', 15),
#              ('hardicanutes', 15),
#              ('putting', 30),
#              ('tar', 30),
#              ('pot', 15),
#              ('been', 270),
#              ('lording', 15),
#              ('schoolmaster', 30),
#              ('making', 75),
#              ('tallest', 15),
#              ('boys', 30),
#              ('awe', 15),
#              ('transition', 30),
#              ('keen', 15),
#              ('assure', 15),
#              ('decoction', 15),
#              ('seneca', 15),
#              ('stoics', 15),
#              ('enable', 15),
#              ('grin', 30),
#              ('bear', 30),
#              ('even', 75),
#              ('wears', 15),
#              ('hunks', 30),
#              ('orders', 15),
#              ('broom', 15),
#              ('sweep', 30),
#              ('decks', 15),
#              ('indignity', 15),
#              ('amount', 15),
#              ('weighed', 30),
#              ('scales', 15),
#              ('new', 165),
#              ('testament', 15),
#              ('think', 105),
#              ('archangel', 15),
#              ('gabriel', 15),
#              ('thinks', 105),
#              ('anything', 30),
#              ('less', 30),
#              ('promptly', 15),
#              ('obey', 15),
#              ('instance', 15),
#              ('ai', 60),
#              ("n't", 360),
#              ('slave', 15),
#              ('well', 120),
#              ('however', 120),
#              ('captains', 15),
#              ('thump', 30),
#              ('punch', 15),
#              ('satisfaction', 15),
#              ('knowing', 45),
#              ('everybody', 15),
#              ('else', 120),
#              ('served', 15),
#              ('either', 45),
#              ('physical', 15),
#              ('point', 30),
#              ('view', 30),
#              ('so', 615),
#              ('universal', 15),
#              ('passed', 45),
#              ('hands', 45),
#              ('rub', 15),
#              ('shoulder', 15),
#              ('blades', 15),
#              ('again', 165),
#              ('always', 60),
#              ('paying', 45),
#              ('trouble', 15),
#              ('whereas', 15),
#              ('pay', 45),
#              ('single', 30),
#              ('penny', 45),
#              ('heard', 120),
#              ('contrary', 15),
#              ('difference', 30),
#              ('between', 135),
#              ('paid', 15),
#              ('act', 30),
#              ('perhaps', 75),
#              ('uncomfortable', 30),
#              ('infliction', 15),
#              ('orchard', 15),
#              ('thieves', 15),
#              ('entailed', 15),
#              ('us', 60),
#              ('paid,--what', 15),
#              ('compare', 30),
#              ('urbane', 15),
#              ('activity', 15),
#              ('receives', 15),
#              ('really', 60),
#              ('marvellous', 60),
#              ('considering', 15),
#              ('earnestly', 15),
#              ('believe', 15),
#              ('root', 15),
#              ('earthly', 30),
#              ('ills', 15),
#              ('monied', 15),
#              ('enter', 30),
#              ('heaven', 60),
#              ('ah', 15),
#              ('cheerfully', 15),
#              ('consign', 15),
#              ('perdition', 15),
#              ('finally', 15),
#              ('wholesome', 15),
#              ('exercise', 15),
#              ('pure', 15),
#              ('air', 60),
#              ('fore', 15),
#              ('castle', 15),
#              ('deck', 30),
#              ('far', 60),
#              ('prevalent', 15),
#              ('astern', 15),
#              ('violate', 15),
#              ('pythagorean', 15),
#              ('maxim', 15),
#              ('quarter', 30),
#              ('gets', 15),
#              ('atmosphere', 15),
#              ('second', 60),
#              ('sailors', 45),
#              ('breathes', 15),
#              ('commonalty', 15),
#              ('leaders', 30),
#              ('many', 60),
#              ('things', 75),
#              ('suspect', 15),
#              ('wherefore', 15),
#              ('after', 135),
#              ('repeatedly', 15),
#              ('smelt', 30),
#              ('merchant', 15),
#              ('whaling', 135),
#              ('invisible', 15),
#              ('police', 15),
#              ('fates', 30),
#              ('has', 60),
#              ('constant', 15),
#              ('surveillance', 15),
#              ('secretly', 15),
#              ('dogs', 15),
#              ('influences', 15),
#              ('unaccountable', 60),
#              ('answer', 75),
#              ('doubtless', 30),
#              ('formed', 30),
#              ('grand', 60),
#              ('programme', 15),
#              ('providence', 15),
#              ('drawn', 15),
#              ('came', 165),
#              ('brief', 15),
#              ('interlude', 15),
#              ('solo', 15),
#              ('extensive', 15),
#              ('performances', 15),
#              ('bill', 15),
#              ('run', 30),
#              ('\n\n\n', 30),
#              ('contested', 15),
#              ('election', 15),
#              ('presidency', 15),
#              ('united', 15),
#              ('states', 15),
#              ('bloody', 15),
#              ('battle', 15),
#              ('affghanistan', 15),
#              ('exactly', 45),
#              ('stage', 30),
#              ('managers', 15),
#              ('put', 120),
#              ('shabby', 30),
#              ('others', 30),
#              ('magnificent', 15),
#              ('parts', 75),
#              ('tragedies', 15),
#              ('short', 45),
#              ('easy', 45),
#              ('genteel', 15),
#              ('comedies', 15),
#              ('jolly', 60),
#              ('farces', 15),
#              ('recall', 15),
#              ('circumstances', 30),
#              ('springs', 15),
#              ('motives', 30),
#              ('cunningly', 15),
#              ('presented', 15),
#              ('various', 30),
#              ('disguises', 15),
#              ('induced', 15),
#              ('performing', 15),
#              ('cajoling', 15),
#              ('delusion', 15),
#              ('choice', 15),
#              ('resulting', 15),
#              ('unbiased', 15),
#              ('freewill', 15),
#              ('discriminating', 15),
#              ('judgment', 15),
#              ('overwhelming', 15),
#              ('idea', 105),
#              ('whale', 150),
#              ('portentous', 45),
#              ('mysterious', 30),
#              ('monster', 15),
#              ('roused', 15),
#              ('curiosity', 30),
#              ('wild', 75),
#              ('seas', 90),
#              ('rolled', 90),
#              ('island', 45),
#              ('bulk', 15),
#              ('undeliverable', 15),
#              ('nameless', 45),
#              ('perils', 15),
#              ('attending', 15),
#              ('marvels', 15),
#              ('patagonian', 15),
#              ('sights', 15),
#              ('sounds', 45),
#              ('helped', 15),
#              ('sway', 15),
#              ('wish', 15),
#              ('inducements', 15),
#              ('tormented', 30),
#              ('everlasting', 30),
#              ('itch', 15),
#              ('remote', 15),
#              ('love', 15),
#              ('forbidden', 15),
#              ('barbarous', 15),
#              ('coasts', 15),
#              ('ignoring', 15),
#              ('good', 255),
#              ('quick', 15),
#              ('perceive', 15),
#              ('horror', 15),
#              ('social', 15),
#              ('since', 45),
#              ('friendly', 15),
#              ('terms', 15),
#              ('inmates', 15),
#              ('place', 225),
#              ('lodges', 15),
#              ('reason', 75),
#              ('welcome', 15),
#              ('flood', 15),
#              ('gates', 15),
#              ('wonder', 30),
#              ('swung', 15),
#              ('open', 60),
#              ('conceits', 15),
#              ('swayed', 15),
#              ('purpose', 30),
#              ('floated', 30),
#              ('inmost', 15),
#              ('endless', 15),
#              ('processions', 15),
#              ('mid', 15),
#              ('hooded', 15),
#              ('snow', 45),
#              ('stuffed', 30),
#              ('shirt', 60),
#              ('carpet', 15),
#              ('bag', 105),
#              ('tucked', 15),
#              ('arm', 165),
#              ('started', 15),
#              ('cape', 60),
#              ('horn', 30),
#              ('pacific', 15),
#              ('quitting', 15),
#              ('manhatto', 15),
#              ('duly', 15),
#              ('arrived', 30),
#              ('bedford', 60),
#              ('saturday', 45),
#              ('night', 360),
#              ('december', 15),
#              ('disappointed', 15),
#              ('learning', 15),
#              ('packet', 15),
#              ('nantucket', 105),
#              ('had', 495),
#              ('already', 15),
#              ('sailed', 15),
#              ('offer', 30),
#              ('till', 90),
#              ('following', 30),
#              ('monday', 15),
#              ('young', 75),
#              ('candidates', 15),
#              ('pains', 15),
#              ('penalties', 15),
#              ('stop', 120),
#              ('embark', 30),
#              ('related', 15),
#              ('doing', 15),
#              ('made', 195),
#              ('craft', 75),
#              ('fine', 60),
#              ('boisterous', 15),
#              ('everything', 15),
#              ('connected', 15),
#              ('famous', 15),
#              ('amazingly', 15),
#              ('pleased', 30),
#              ('late', 105),
#              ('gradually', 15),
#              ('monopolising', 15),
#              ('business', 75),
#              ('matter', 45),
#              ('behind', 15),
#              ('original', 30),
#              ('tyre', 15),
#              ('carthage;--the', 15),
#              ('dead', 75),
#              ('stranded', 30),
#              ('aboriginal', 15),
#              ('whalemen', 15),
#              ('red', 45),
#              ('sally', 15),
#              ('canoes', 15),
#              ('chase', 15),
#              ('leviathan', 30),
#              ('too', 210),
#              ('adventurous', 15),
#              ('sloop', 15),
#              ('forth', 15),
#              ('partly', 45),
#              ('laden', 15),
#              ('imported', 15),
#              ('cobblestones', 15),
#              ('throw', 15),
#              ('whales', 30),
#              ('discover', 15),
#              ('risk', 15),
#              ('harpoon', 80),
#              ('bowsprit', 15),
#              ('day', 90),
#              ('another', 75),
#              ('ere', 45),
#              ('destined', 15),
#              ('port', 15),
#              ('became', 45),
#              ('concernment', 15),
#              ('eat', 15),
#              ('meanwhile', 45),
#              ('dubious', 15),
#              ('nay', 30),
#              ('dark', 120),
#              ('dismal', 30),
#              ('bitingly', 15),
#              ('cold', 105),
#              ('cheerless', 15),
#              ('anxious', 15),
#              ('grapnels', 15),
#              ('sounded', 15),
#              ('pocket', 45),
#              ('only', 210),
#              ('brought', 15),
#              ('pieces', 15),
#              ('silver,--so', 15),
#              ('wherever', 30),
#              ('said', 285),
#              ('stood', 150),
#              ('middle', 75),
#              ('dreary', 30),
#              ('shouldering', 15),
#              ('comparing', 15),
#              ('gloom', 15),
#              ('darkness', 45),
#              ('wisdom', 15),
#              ('conclude', 15),
#              ('lodge', 15),
#              ('dear', 15),
#              ('sure', 75),
#              ('inquire', 15),
#              ('price', 15),
#              ('halting', 15),
#              ('steps', 15),
#              ('paced', 15),
#              ('sign', 90),
#              ('crossed', 30),
#              ('harpoons"--but', 15),
#              ('looked', 90),
#              ('expensive', 30),
#              ('further', 60),
#              ('bright', 30),
#              ('windows', 30),
#              ('fish', 45),
#              ('inn', 45),
#              ('fervent', 15),
#              ('rays', 15),
#              ('seemed', 240),
#              ('melted', 15),
#              ('packed', 30),
#              ('ice', 60),
#              ('house', 165),
#              ('everywhere', 15),
#              ('congealed', 15),
#              ('frost', 60),
#              ('lay', 135),
#              ('inches', 30),
#              ...])

# %%
# Printing the word occurence in different number of documents/sentences
text_tokenizer.word_docs
# Out:
# defaultdict(int,
#             {'years': 80,
#              'ago': 51,
#              'or': 477,
#              'long': 211,
#              'having': 87,
#              'little': 432,
#              'no': 584,
#              'me': 1250,
#              'call': 16,
#              'ishmael': 78,
#              'mind': 98,
#              'some': 414,
#              'precisely': 26,
#              'never': 262,
#              'how': 189,
#              'money': 70,
#              'in': 3008,
#              'my': 982,
#              'purse': 33,
#              'and': 4784,
#              'nothing': 156,
#              'particular': 90,
#              'to': 3271,
#              'interest': 15,
#              'on': 972,
#              'shore': 15,
#              'i': 3599,
#              'thought': 385,
#              'would': 399,
#              'sail': 60,
#              'about': 578,
#              'a': 4711,
#              'see': 230,
#              'the': 6273,
#              'watery': 15,
#              'part': 135,
#              'of': 4064,
#              'world': 135,
#              'it': 2225,
#              'is': 1048,
#              'way': 218,
#              'have': 461,
#              'driving': 15,
#              'off': 240,
#              'spleen': 15,
#              'regulating': 15,
#              'circulation': 15,
#              'whenever': 64,
#              'find': 45,
#              'myself': 236,
#              'growing': 15,
#              'grim': 15,
#              'mouth': 75,
#              'damp': 45,
#              'drizzly': 15,
#              'november': 15,
#              'soul': 45,
#              'involuntarily': 30,
#              'pausing': 30,
#              'before': 210,
#              'coffin': 50,
#              'warehouses': 30,
#              'bringing': 15,
#              'up': 715,
#              'rear': 15,
#              'every': 105,
#              'funeral': 15,
#              'meet': 15,
#              'especially': 60,
#              'hypos': 15,
#              'get': 210,
#              'such': 319,
#              'an': 465,
#              'upper': 15,
#              'hand': 180,
#              'that': 2028,
#              'requires': 30,
#              'strong': 45,
#              'moral': 15,
#              'principle': 15,
#              'prevent': 15,
#              'from': 837,
#              'deliberately': 15,
#              'stepping': 15,
#              'into': 564,
#              'street': 60,
#              'methodically': 15,
#              'knocking': 15,
#              'people': 30,
#              "'s": 857,
#              'hats': 15,
#              'then': 473,
#              'account': 45,
#              'high': 75,
#              'time': 300,
#              'sea': 315,
#              'as': 1157,
#              'soon': 135,
#              'can': 195,
#              'this': 1218,
#              'substitute': 15,
#              'for': 1013,
#              'pistol': 15,
#              'ball': 15,
#              'with': 1320,
#              'philosophical': 15,
#              'flourish': 15,
#              'cato': 15,
#              'throws': 15,
#              'himself': 195,
#              'upon': 447,
#              'his': 1568,
#              'sword': 45,
#              'quietly': 45,
#              'take': 150,
#              'ship': 105,
#              'there': 822,
#              'surprising': 15,
#              'if': 420,
#              'they': 377,
#              'but': 1485,
#              'knew': 75,
#              'almost': 165,
#              'all': 1071,
#              'men': 75,
#              'their': 212,
#              'degree': 45,
#              'other': 285,
#              'cherish': 15,
#              'very': 271,
#              'nearly': 30,
#              'same': 176,
#              'feelings': 15,
#              'towards': 141,
#              'ocean': 30,
#              'now': 600,
#              'your': 226,
#              'insular': 15,
#              'city': 60,
#              'manhattoes': 15,
#              'belted': 15,
#              'round': 210,
#              'by': 506,
#              'wharves': 15,
#              'indian': 30,
#              'isles': 15,
#              'coral': 15,
#              'reefs': 15,
#              'commerce': 15,
#              'surrounds': 15,
#              'her': 67,
#              'surf': 15,
#              'right': 90,
#              'left': 45,
#              'streets': 120,
#              'you': 1085,
#              'waterward': 30,
#              'its': 90,
#              'extreme': 15,
#              'downtown': 15,
#              'battery': 30,
#              'where': 203,
#              'noble': 30,
#              'mole': 15,
#              'washed': 30,
#              'waves': 15,
#              'cooled': 15,
#              'breezes': 15,
#              'which': 327,
#              'few': 60,
#              'hours': 71,
#              'previous': 60,
#              'were': 534,
#              'out': 549,
#              'sight': 60,
#              'land': 120,
#              'look': 90,
#              'at': 1245,
#              'crowds': 30,
#              'water': 122,
#              'gazers': 15,
#              'circumambulate': 15,
#              'dreamy': 15,
#              'sabbath': 30,
#              'afternoon': 30,
#              'go': 267,
#              'corlears': 15,
#              'hook': 15,
#              'coenties': 15,
#              'slip': 15,
#              'thence': 30,
#              'whitehall': 15,
#              'northward': 15,
#              'what': 638,
#              'do': 405,
#              'see?--posted': 15,
#              'like': 424,
#              'silent': 30,
#              'sentinels': 15,
#              'around': 45,
#              'town': 90,
#              'stand': 105,
#              'thousands': 17,
#              'mortal': 15,
#              'fixed': 45,
#              'reveries': 30,
#              'leaning': 30,
#              'against': 135,
#              'spiles': 15,
#              'seated': 30,
#              'pier': 15,
#              'heads': 178,
#              'looking': 180,
#              'over': 405,
#              'bulwarks': 30,
#              'ships': 45,
#              'china': 15,
#              'aloft': 30,
#              'rigging': 15,
#              'striving': 15,
#              'still': 210,
#              'better': 120,
#              'seaward': 15,
#              'peep': 15,
#              'these': 279,
#              'are': 240,
#              'landsmen': 15,
#              'week': 30,
#              'days': 60,
#              'pent': 15,
#              'lath': 15,
#              'plaster': 30,
#              'tied': 15,
#              'counters': 15,
#              'nailed': 15,
#              'benches': 15,
#              'clinched': 15,
#              'desks': 15,
#              'green': 75,
#              'fields': 15,
#              'gone': 30,
#              'here': 322,
#              'come': 161,
#              'more': 256,
#              'pacing': 15,
#              'straight': 60,
#              'seemingly': 15,
#              'bound': 30,
#              'dive': 15,
#              'strange': 94,
#              'will': 149,
#              'content': 30,
#              'them': 255,
#              'extremest': 15,
#              'limit': 15,
#              'loitering': 15,
#              'under': 150,
#              'shady': 15,
#              'lee': 15,
#              'yonder': 30,
#              'not': 851,
#              'suffice': 15,
#              'must': 255,
#              'just': 216,
#              'nigh': 60,
#              'possibly': 15,
#              'without': 105,
#              'falling': 30,
#              'miles': 45,
#              'leagues': 15,
#              'inlanders': 15,
#              'lanes': 15,
#              'alleys': 15,
#              'avenues': 15,
#              'north': 30,
#              'east': 15,
#              'south': 90,
#              'west': 15,
#              'yet': 240,
#              'unite': 15,
#              'tell': 254,
#              'does': 90,
#              'magnetic': 15,
#              'virtue': 15,
#              'needles': 15,
#              'compasses': 15,
#              'those': 135,
#              'attract': 15,
#              'thither': 15,
#              'once': 120,
#              'say': 165,
#              'country': 45,
#              'lakes': 15,
#              'any': 209,
#              'path': 15,
#              'please': 30,
#              'ten': 30,
#              'one': 720,
#              'carries': 15,
#              'down': 265,
#              'dale': 15,
#              'leaves': 30,
#              'pool': 15,
#              'stream': 45,
#              'magic': 30,
#              'let': 90,
#              'most': 270,
#              'absent': 15,
#              'minded': 15,
#              'be': 927,
#              'plunged': 30,
#              'deepest': 15,
#              'man': 330,
#              'legs': 60,
#              'set': 90,
#              'feet': 101,
#              'going': 150,
#              'he': 1645,
#              'infallibly': 15,
#              'lead': 45,
#              'region': 15,
#              'should': 165,
#              'ever': 195,
#              'athirst': 15,
#              'great': 222,
#              'american': 45,
#              'desert': 15,
#              'try': 60,
#              'experiment': 15,
#              'caravan': 15,
#              'happen': 15,
#              'supplied': 15,
#              'metaphysical': 30,
#              'professor': 15,
#              'yes': 60,
#              'knows': 15,
#              'meditation': 15,
#              'wedded': 15,
#              'artist': 45,
#              'desires': 15,
#              'paint': 15,
#              'dreamiest': 15,
#              'shadiest': 15,
#              'quietest': 15,
#              'enchanting': 15,
#              'bit': 75,
#              'romantic': 15,
#              'landscape': 15,
#              'valley': 15,
#              'saco': 15,
#              'chief': 30,
#              'element': 15,
#              'employs': 15,
#              'trees': 15,
#              'each': 45,
#              'hollow': 15,
#              'trunk': 30,
#              'hermit': 15,
#              'crucifix': 15,
#              'within': 75,
#              'sleeps': 15,
#              'meadow': 30,
#              'sleep': 237,
#              'cattle': 15,
#              'cottage': 15,
#              'goes': 45,
#              'sleepy': 15,
#              'smoke': 30,
#              'deep': 45,
#              'distant': 45,
#              'woodlands': 15,
#              'winds': 36,
#              'mazy': 15,
#              'reaching': 30,
#              'overlapping': 15,
#              'spurs': 15,
#              'mountains': 15,
#              'bathed': 15,
#              'hill': 30,
#              'side': 165,
#              'blue': 45,
#              'though': 276,
#              'picture': 75,
#              'lies': 15,
#              'thus': 30,
#              'tranced': 15,
#              'pine': 30,
#              'tree': 15,
#              'shakes': 15,
#              'sighs': 30,
#              'shepherd': 24,
#              'head': 345,
#              'vain': 15,
#              'unless': 60,
#              'eye': 15,
#              'him': 601,
#              'visit': 15,
#              'prairies': 15,
#              'june': 30,
#              'when': 365,
#              'scores': 17,
#              'wade': 15,
#              'knee': 15,
#              'among': 45,
#              'tiger': 15,
#              'lilies': 15,
#              'charm': 15,
#              'wanting?--water': 15,
#              'drop': 15,
#              'niagara': 15,
#              'cataract': 15,
#              'sand': 15,
#              'travel': 15,
#              'thousand': 30,
#              'why': 159,
#              'did': 324,
#              'poor': 60,
#              'poet': 15,
#              'tennessee': 15,
#              'suddenly': 45,
#              'receiving': 15,
#              'two': 180,
#              'handfuls': 15,
#              'silver': 15,
#              'deliberate': 15,
#              'whether': 105,
#              'buy': 15,
#              'coat': 60,
#              'sadly': 30,
#              'needed': 15,
#              'invest': 15,
#              'pedestrian': 15,
#              'trip': 15,
#              'rockaway': 15,
#              'beach': 15,
#              'robust': 20,
#              'healthy': 20,
#              'boy': 30,
#              'crazy': 30,
#              'first': 284,
#              'voyage': 120,
#              'passenger': 51,
#              'yourself': 90,
#              'feel': 45,
#              'mystical': 15,
#              'vibration': 15,
#              'told': 75,
#              'old': 427,
#              'persians': 15,
#              'hold': 30,
#              'holy': 30,
#              'greeks': 15,
#              'give': 120,
#              'separate': 15,
#              'deity': 15,
#              'own': 137,
#              'brother': 30,
#              'jove': 15,
#              'surely': 15,
#              'meaning': 35,
#              'deeper': 15,
#              'story': 75,
#              'narcissus': 15,
#              'who': 240,
#              'because': 105,
#              'could': 375,
#              'grasp': 15,
#              'tormenting': 15,
#              'mild': 15,
#              'image': 87,
#              'saw': 90,
#              'fountain': 15,
#              'was': 1567,
#              'drowned': 15,
#              'we': 165,
#              'ourselves': 30,
#              'rivers': 15,
#              'oceans': 15,
#              'ungraspable': 15,
#              'phantom': 45,
#              'life': 45,
#              'key': 15,
#              'am': 90,
#              'habit': 15,
#              'begin': 23,
#              'grow': 30,
#              'hazy': 15,
#              'eyes': 105,
#              'conscious': 15,
#              'lungs': 15,
#              'mean': 75,
#              'inferred': 30,
#              'needs': 30,
#              'rag': 15,
#              'something': 180,
#              'besides': 90,
#              'passengers': 42,
#              'sick': 15,
#              'quarrelsome': 15,
#              "don't": 30,
#              'nights': 15,
#              'enjoy': 15,
#              'themselves': 30,
#              'much': 255,
#              'general': 15,
#              'thing;--no': 15,
#              'nor': 45,
#              'salt': 15,
#              'commodore': 30,
#              'captain': 30,
#              'cook': 30,
#              'abandon': 15,
#              'glory': 30,
#              'distinction': 15,
#              'offices': 15,
#              'abominate': 15,
#              'honourable': 15,
#              'respectable': 15,
#              'toils': 15,
#              'trials': 15,
#              'tribulations': 15,
#              'kind': 45,
#              'whatsoever': 30,
#              'quite': 45,
#              'care': 35,
#              'taking': 60,
#              'barques': 15,
#              'brigs': 15,
#              'schooners': 15,
#              'cook,--though': 15,
#              'confess': 30,
#              'considerable': 15,
#              'being': 225,
#              'sort': 285,
#              'officer': 30,
#              'board': 45,
#              'somehow': 45,
#              'fancied': 15,
#              'broiling': 15,
#              'fowls;--though': 15,
#              'broiled': 45,
#              'judiciously': 15,
#              'buttered': 15,
#              'judgmatically': 15,
#              'salted': 15,
#              'peppered': 15,
#              'speak': 75,
#              'respectfully': 30,
#              'reverentially': 15,
#              'fowl': 15,
#              'than': 224,
#              'idolatrous': 15,
#              'dotings': 15,
#              'egyptians': 15,
#              'ibis': 15,
#              'roasted': 15,
#              'river': 15,
#              'horse': 30,
#              'mummies': 15,
#              'creatures': 15,
#              'huge': 30,
#              'bake': 15,
#              'houses': 30,
#              'pyramids': 15,
#              'simple': 15,
#              'sailor': 90,
#              'mast': 41,
#              'plumb': 15,
#              'forecastle': 30,
#              'royal': 15,
#              'true': 60,
#              'rather': 115,
#              'order': 75,
#              'make': 150,
#              'jump': 30,
#              'spar': 17,
#              'grasshopper': 15,
#              'may': 171,
#              'thing': 60,
#              'unpleasant': 15,
#              'enough': 187,
#              'touches': 15,
#              'sense': 45,
#              'honour': 15,
#              'particularly': 30,
#              'established': 15,
#              'family': 15,
#              'van': 15,
#              'rensselaers': 15,
#              'randolphs': 15,
#              'hardicanutes': 15,
#              'putting': 30,
#              'tar': 30,
#              'pot': 15,
#              'been': 270,
#              'lording': 15,
#              'schoolmaster': 30,
#              'making': 75,
#              'tallest': 15,
#              'boys': 30,
#              'awe': 15,
#              'transition': 30,
#              'keen': 15,
#              'assure': 15,
#              'decoction': 15,
#              'seneca': 15,
#              'stoics': 15,
#              'enable': 15,
#              'grin': 30,
#              'bear': 30,
#              'even': 75,
#              'wears': 15,
#              'hunks': 30,
#              'orders': 15,
#              'broom': 15,
#              'sweep': 30,
#              'decks': 15,
#              'indignity': 15,
#              'amount': 15,
#              'weighed': 30,
#              'scales': 15,
#              'new': 165,
#              'testament': 15,
#              'think': 105,
#              'archangel': 15,
#              'gabriel': 15,
#              'thinks': 105,
#              'anything': 30,
#              'less': 30,
#              'promptly': 15,
#              'obey': 15,
#              'instance': 15,
#              'ai': 60,
#              "n't": 345,
#              'slave': 15,
#              'well': 120,
#              'however': 114,
#              'captains': 15,
#              'thump': 30,
#              'punch': 15,
#              'satisfaction': 15,
#              'knowing': 45,
#              'everybody': 15,
#              'else': 120,
#              'served': 15,
#              'either': 45,
#              'physical': 15,
#              'point': 30,
#              'view': 30,
#              'so': 615,
#              'universal': 15,
#              'passed': 45,
#              'hands': 45,
#              'rub': 15,
#              'shoulder': 15,
#              'blades': 15,
#              'again': 165,
#              'always': 60,
#              'paying': 37,
#              'trouble': 15,
#              'whereas': 15,
#              'pay': 45,
#              'single': 30,
#              'penny': 34,
#              'heard': 120,
#              'contrary': 15,
#              'difference': 30,
#              'between': 135,
#              'paid': 15,
#              'act': 30,
#              'perhaps': 75,
#              'uncomfortable': 30,
#              'infliction': 15,
#              'orchard': 15,
#              'thieves': 15,
#              'entailed': 15,
#              'us': 60,
#              'paid,--what': 15,
#              'compare': 30,
#              'urbane': 15,
#              'activity': 15,
#              'receives': 15,
#              'really': 55,
#              'marvellous': 60,
#              'considering': 15,
#              'earnestly': 15,
#              'believe': 15,
#              'root': 15,
#              'earthly': 30,
#              'ills': 15,
#              'monied': 15,
#              'enter': 30,
#              'heaven': 60,
#              'ah': 15,
#              'cheerfully': 15,
#              'consign': 15,
#              'perdition': 15,
#              'finally': 15,
#              'wholesome': 15,
#              'exercise': 15,
#              'pure': 15,
#              'air': 60,
#              'fore': 15,
#              'castle': 15,
#              'deck': 30,
#              'far': 60,
#              'prevalent': 15,
#              'astern': 15,
#              'violate': 15,
#              'pythagorean': 15,
#              'maxim': 15,
#              'quarter': 30,
#              'gets': 15,
#              'atmosphere': 15,
#              'second': 60,
#              'sailors': 45,
#              'breathes': 15,
#              'commonalty': 15,
#              'leaders': 26,
#              'many': 60,
#              'things': 75,
#              'suspect': 15,
#              'wherefore': 15,
#              'after': 135,
#              'repeatedly': 15,
#              'smelt': 30,
#              'merchant': 15,
#              'whaling': 135,
#              'invisible': 15,
#              'police': 15,
#              'fates': 30,
#              'has': 60,
#              'constant': 15,
#              'surveillance': 15,
#              'secretly': 15,
#              'dogs': 15,
#              'influences': 15,
#              'unaccountable': 60,
#              'answer': 75,
#              'doubtless': 30,
#              'formed': 30,
#              'grand': 60,
#              'programme': 15,
#              'providence': 15,
#              'drawn': 15,
#              'came': 165,
#              'brief': 15,
#              'interlude': 15,
#              'solo': 15,
#              'extensive': 15,
#              'performances': 15,
#              'bill': 15,
#              'run': 30,
#              '\n\n\n': 30,
#              'contested': 15,
#              'election': 15,
#              'presidency': 15,
#              'united': 15,
#              'states': 15,
#              'bloody': 15,
#              'battle': 15,
#              'affghanistan': 15,
#              'exactly': 45,
#              'stage': 30,
#              'managers': 15,
#              'put': 120,
#              'shabby': 30,
#              'others': 30,
#              'magnificent': 15,
#              'parts': 59,
#              'tragedies': 15,
#              'short': 45,
#              'easy': 32,
#              'genteel': 15,
#              'comedies': 15,
#              'jolly': 60,
#              'farces': 15,
#              'recall': 15,
#              'circumstances': 30,
#              'springs': 15,
#              'motives': 30,
#              'cunningly': 15,
#              'presented': 15,
#              'various': 30,
#              'disguises': 15,
#              'induced': 15,
#              'performing': 15,
#              'cajoling': 15,
#              'delusion': 15,
#              'choice': 15,
#              'resulting': 15,
#              'unbiased': 15,
#              'freewill': 15,
#              'discriminating': 15,
#              'judgment': 15,
#              'overwhelming': 15,
#              'idea': 105,
#              'whale': 150,
#              'portentous': 45,
#              'mysterious': 30,
#              'monster': 15,
#              'roused': 15,
#              'curiosity': 30,
#              'wild': 75,
#              'seas': 90,
#              'rolled': 90,
#              'island': 45,
#              'bulk': 15,
#              'undeliverable': 15,
#              'nameless': 45,
#              'perils': 15,
#              'attending': 15,
#              'marvels': 15,
#              'patagonian': 15,
#              'sights': 15,
#              'sounds': 45,
#              'helped': 15,
#              'sway': 15,
#              'wish': 15,
#              'inducements': 15,
#              'tormented': 30,
#              'everlasting': 30,
#              'itch': 15,
#              'remote': 15,
#              'love': 15,
#              'forbidden': 15,
#              'barbarous': 15,
#              'coasts': 15,
#              'ignoring': 15,
#              'good': 251,
#              'quick': 15,
#              'perceive': 15,
#              'horror': 15,
#              'social': 15,
#              'since': 45,
#              'friendly': 15,
#              'terms': 15,
#              'inmates': 15,
#              'place': 225,
#              'lodges': 15,
#              'reason': 75,
#              'welcome': 15,
#              'flood': 15,
#              'gates': 15,
#              'wonder': 30,
#              'swung': 15,
#              'open': 60,
#              'conceits': 15,
#              'swayed': 15,
#              'purpose': 30,
#              'floated': 30,
#              'inmost': 15,
#              'endless': 15,
#              'processions': 15,
#              'mid': 15,
#              'hooded': 15,
#              'snow': 45,
#              'stuffed': 30,
#              'shirt': 60,
#              'carpet': 15,
#              'bag': 105,
#              'tucked': 15,
#              'arm': 165,
#              'started': 15,
#              'cape': 60,
#              'horn': 30,
#              'pacific': 15,
#              'quitting': 15,
#              'manhatto': 15,
#              'duly': 15,
#              'arrived': 30,
#              'bedford': 60,
#              'saturday': 45,
#              'night': 351,
#              'december': 15,
#              'disappointed': 15,
#              'learning': 15,
#              'packet': 15,
#              'nantucket': 97,
#              'had': 470,
#              'already': 15,
#              'sailed': 15,
#              'offer': 30,
#              'till': 90,
#              'following': 30,
#              'monday': 15,
#              'young': 75,
#              'candidates': 15,
#              'pains': 15,
#              'penalties': 15,
#              'stop': 120,
#              'embark': 30,
#              'related': 15,
#              'doing': 15,
#              'made': 195,
#              'craft': 75,
#              'fine': 60,
#              'boisterous': 15,
#              'everything': 15,
#              'connected': 15,
#              'famous': 15,
#              'amazingly': 15,
#              'pleased': 30,
#              'late': 105,
#              'gradually': 15,
#              'monopolising': 15,
#              'business': 75,
#              'matter': 45,
#              'behind': 15,
#              'original': 30,
#              'tyre': 15,
#              'carthage;--the': 15,
#              'dead': 75,
#              'stranded': 30,
#              'aboriginal': 15,
#              'whalemen': 15,
#              'red': 45,
#              'sally': 15,
#              'canoes': 15,
#              'chase': 15,
#              'leviathan': 30,
#              'too': 210,
#              'adventurous': 15,
#              'sloop': 15,
#              'forth': 15,
#              'partly': 45,
#              'laden': 15,
#              'imported': 15,
#              'cobblestones': 15,
#              'throw': 15,
#              'whales': 30,
#              'discover': 15,
#              'risk': 15,
#              'harpoon': 80,
#              'bowsprit': 15,
#              'day': 90,
#              'another': 75,
#              'ere': 45,
#              'destined': 15,
#              'port': 15,
#              'became': 45,
#              'concernment': 15,
#              'eat': 15,
#              'meanwhile': 45,
#              'dubious': 15,
#              'nay': 30,
#              'dark': 120,
#              'dismal': 30,
#              'bitingly': 15,
#              'cold': 105,
#              'cheerless': 15,
#              'anxious': 15,
#              'grapnels': 15,
#              'sounded': 15,
#              'pocket': 45,
#              'only': 210,
#              'brought': 15,
#              'pieces': 15,
#              'silver,--so': 15,
#              'wherever': 30,
#              'said': 273,
#              'stood': 150,
#              'middle': 75,
#              'dreary': 30,
#              'shouldering': 15,
#              'comparing': 15,
#              'gloom': 15,
#              'darkness': 45,
#              'wisdom': 15,
#              'conclude': 15,
#              'lodge': 15,
#              'dear': 15,
#              'sure': 75,
#              'inquire': 15,
#              'price': 15,
#              'halting': 15,
#              'steps': 15,
#              'paced': 15,
#              'sign': 90,
#              'crossed': 30,
#              'harpoons"--but': 15,
#              'looked': 79,
#              'expensive': 30,
#              'further': 60,
#              'bright': 30,
#              'windows': 30,
#              'fish': 45,
#              'inn': 45,
#              'fervent': 15,
#              'rays': 15,
#              'seemed': 234,
#              'melted': 15,
#              'packed': 30,
#              'ice': 60,
#              'house': 165,
#              'everywhere': 15,
#              'congealed': 15,
#              'frost': 60,
#              'lay': 135,
#              'inches': 30,
#              ...})

# %%
corpus_size = len(text_tokenizer.word_counts)
corpus_size
# Out:
# 2718

# %%
# Creating sequences into Numpy arrays for better processing
final_sequences = np.array(tokenized_sequences)

# %%
final_sequences
# Out:
# array([[ 956,   14,  262, ...,   50,   43,   37],
#        [  14,  262,   51, ...,   43,   37,  263],
#        [ 262,   51,  260, ...,   37,  263,    7],
#        ...,
#        [  61,  943,   31, ...,  261,   53,    2],
#        [ 943,   31,    7, ...,   53,    2, 2718],
#        [  31,    7,   11, ...,    2, 2718,   26]])

# %%
final_sequences.shape
# Out:
# (11313, 15)

# %% [markdown]
# ## Converting the sequences into Features & Labels

# %%
from tensorflow.keras.utils import to_categorical

# %%
features = final_sequences[:, : -1]
labels = final_sequences[:, -1]

# %%
labels
# Out:
# array([  37,  263,    7, ...,    2, 2718,   26])

# %%
features
# Out:
# array([[ 956,   14,  262, ...,  259,   50,   43],
#        [  14,  262,   51, ...,   50,   43,   37],
#        [ 262,   51,  260, ...,   43,   37,  263],
#        ...,
#        [  61,  943,   31, ...,   11,  261,   53],
#        [ 943,   31,    7, ...,  261,   53,    2],
#        [  31,    7,   11, ...,   53,    2, 2718]])

# %%
corpus_size
# Out:
# 2718

# %%
"""# Adding 1 here to incorporate 0 also, othersiwe, error will be there"""
labels = to_categorical(labels, num_classes = corpus_size + 1)

# %%
labels[0].shape
# Out:
# (2719,)

# %%
sequence_length = features.shape[1]

# %%
sequence_length
# Out:
# 14

# %% [markdown]
# ## Generating LSTM Models

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding

# %%
# sequence_length * 3, corpus_size + 1

# %%
model = Sequential([
                        Embedding(input_dim = corpus_size + 1,
                                  output_dim = sequence_length,
                                  input_length = sequence_length),
    
     # return_sequences = True is required only for the first time because without it,
     # only number of neurons will be returned."""
                        LSTM(units = 95, return_sequences = True),
    
                        LSTM(units = 95),
                        
                        Dense(units = 100, activation = "relu"),
                        
                        Dense(units = corpus_size + 1, activation = "softmax")
])

model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 14, 14)            38066
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 14, 95)            41800
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 95)                72580
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               9600
# _________________________________________________________________
# dense_17 (Dense)             (None, 2719)              274619
# =================================================================
# Total params: 436,665
# Trainable params: 436,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
MC = ModelCheckpoint(filepath = "Text-Generator.h5", monitor = "loss", verbose = 1)

# %%
history = model.fit(features, labels, epochs = 150, verbose = 1, callbacks = [MC])
# Out:
# 2021-09-02 21:34:44.391275: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/150
# 354/354 [==============================] - 24s 52ms/step - loss: 6.7496 - accuracy: 0.0513
#
# Epoch 00001: saving model to Text-Generator.h5
# Epoch 2/150
# 354/354 [==============================] - 20s 56ms/step - loss: 6.2765 - accuracy: 0.0529
#
# Epoch 00002: saving model to Text-Generator.h5
# Epoch 3/150
# 354/354 [==============================] - 15s 41ms/step - loss: 6.1306 - accuracy: 0.0538
#
# Epoch 00003: saving model to Text-Generator.h5
# Epoch 4/150
# 354/354 [==============================] - 14s 39ms/step - loss: 5.9834 - accuracy: 0.0595
#
# Epoch 00004: saving model to Text-Generator.h5
# Epoch 5/150
# 354/354 [==============================] - 12s 33ms/step - loss: 5.8643 - accuracy: 0.0662
#
# Epoch 00005: saving model to Text-Generator.h5
# Epoch 6/150
# 354/354 [==============================] - 14s 39ms/step - loss: 5.7639 - accuracy: 0.0695
#
# Epoch 00006: saving model to Text-Generator.h5
# Epoch 7/150
# 354/354 [==============================] - 21s 58ms/step - loss: 5.6656 - accuracy: 0.0728
#
# Epoch 00007: saving model to Text-Generator.h5
# Epoch 8/150
# 354/354 [==============================] - 14s 40ms/step - loss: 5.5835 - accuracy: 0.0758
#
# Epoch 00008: saving model to Text-Generator.h5
# Epoch 9/150
# 354/354 [==============================] - 10s 27ms/step - loss: 5.5112 - accuracy: 0.0783
#
# Epoch 00009: saving model to Text-Generator.h5
# Epoch 10/150
# 354/354 [==============================] - 10s 28ms/step - loss: 5.4388 - accuracy: 0.0798
#
# Epoch 00010: saving model to Text-Generator.h5
# Epoch 11/150
# 354/354 [==============================] - 9s 26ms/step - loss: 5.3700 - accuracy: 0.0839
#
# Epoch 00011: saving model to Text-Generator.h5
# Epoch 12/150
# 354/354 [==============================] - 9s 26ms/step - loss: 5.3073 - accuracy: 0.0857
#
# Epoch 00012: saving model to Text-Generator.h5
# Epoch 13/150
# 354/354 [==============================] - 12s 33ms/step - loss: 5.2458 - accuracy: 0.0862
#
# Epoch 00013: saving model to Text-Generator.h5
# Epoch 14/150
# 354/354 [==============================] - 22s 64ms/step - loss: 5.1881 - accuracy: 0.0902
#
# Epoch 00014: saving model to Text-Generator.h5
# Epoch 15/150
# 354/354 [==============================] - 19s 54ms/step - loss: 5.1293 - accuracy: 0.0907
#
# Epoch 00015: saving model to Text-Generator.h5
# Epoch 16/150
# 354/354 [==============================] - 22s 63ms/step - loss: 5.0774 - accuracy: 0.0907
#
# Epoch 00016: saving model to Text-Generator.h5
# Epoch 17/150
# 354/354 [==============================] - 26s 73ms/step - loss: 5.0231 - accuracy: 0.0918
#
# Epoch 00017: saving model to Text-Generator.h5
# Epoch 18/150
# 354/354 [==============================] - 18s 51ms/step - loss: 4.9696 - accuracy: 0.0948
#
# Epoch 00018: saving model to Text-Generator.h5
# Epoch 19/150
# 354/354 [==============================] - 20s 56ms/step - loss: 4.9209 - accuracy: 0.0933
#
# Epoch 00019: saving model to Text-Generator.h5
# Epoch 20/150
# 354/354 [==============================] - 24s 67ms/step - loss: 4.8678 - accuracy: 0.0975
#
# Epoch 00020: saving model to Text-Generator.h5
# Epoch 21/150
# 354/354 [==============================] - 19s 53ms/step - loss: 4.8203 - accuracy: 0.0963
#
# Epoch 00021: saving model to Text-Generator.h5
# Epoch 22/150
# 354/354 [==============================] - 19s 53ms/step - loss: 4.7732 - accuracy: 0.0973
#
# Epoch 00022: saving model to Text-Generator.h5
# Epoch 23/150
# 354/354 [==============================] - 20s 57ms/step - loss: 4.7289 - accuracy: 0.0996
#
# Epoch 00023: saving model to Text-Generator.h5
# Epoch 24/150
# 354/354 [==============================] - 20s 57ms/step - loss: 4.6888 - accuracy: 0.0994
#
# Epoch 00024: saving model to Text-Generator.h5
# Epoch 25/150
# 354/354 [==============================] - 19s 54ms/step - loss: 4.6460 - accuracy: 0.1014
#
# Epoch 00025: saving model to Text-Generator.h5
# Epoch 26/150
# 354/354 [==============================] - 16s 45ms/step - loss: 4.6062 - accuracy: 0.1002
#
# Epoch 00026: saving model to Text-Generator.h5
# Epoch 27/150
# 354/354 [==============================] - 14s 39ms/step - loss: 4.5681 - accuracy: 0.1010
#
# Epoch 00027: saving model to Text-Generator.h5
# Epoch 28/150
# 354/354 [==============================] - 13s 38ms/step - loss: 4.5352 - accuracy: 0.1019
#
# Epoch 00028: saving model to Text-Generator.h5
# Epoch 29/150
# 354/354 [==============================] - 13s 37ms/step - loss: 4.4970 - accuracy: 0.1043
#
# Epoch 00029: saving model to Text-Generator.h5
# Epoch 30/150
# 354/354 [==============================] - 12s 34ms/step - loss: 4.4699 - accuracy: 0.1071
#
# Epoch 00030: saving model to Text-Generator.h5
# Epoch 31/150
# 354/354 [==============================] - 12s 35ms/step - loss: 4.4323 - accuracy: 0.1073
#
# Epoch 00031: saving model to Text-Generator.h5
# Epoch 32/150
# 354/354 [==============================] - 12s 35ms/step - loss: 4.4034 - accuracy: 0.1080
#
# Epoch 00032: saving model to Text-Generator.h5
# Epoch 33/150
# 354/354 [==============================] - 12s 34ms/step - loss: 4.3683 - accuracy: 0.1097
#
# Epoch 00033: saving model to Text-Generator.h5
# Epoch 34/150
# 354/354 [==============================] - 13s 35ms/step - loss: 4.3408 - accuracy: 0.1105
#
# Epoch 00034: saving model to Text-Generator.h5
# Epoch 35/150
# 354/354 [==============================] - 12s 33ms/step - loss: 4.3119 - accuracy: 0.1095
#
# Epoch 00035: saving model to Text-Generator.h5
# Epoch 36/150
# 354/354 [==============================] - 12s 33ms/step - loss: 4.2796 - accuracy: 0.1137
#
# Epoch 00036: saving model to Text-Generator.h5
# Epoch 37/150
# 354/354 [==============================] - 13s 38ms/step - loss: 4.2509 - accuracy: 0.1149
#
# Epoch 00037: saving model to Text-Generator.h5
# Epoch 38/150
# 354/354 [==============================] - 12s 34ms/step - loss: 4.2221 - accuracy: 0.1115
#
# Epoch 00038: saving model to Text-Generator.h5
# Epoch 39/150
# 354/354 [==============================] - 12s 33ms/step - loss: 4.1915 - accuracy: 0.1184
#
# Epoch 00039: saving model to Text-Generator.h5
# Epoch 40/150
# 354/354 [==============================] - 12s 34ms/step - loss: 4.1668 - accuracy: 0.1153
#
# Epoch 00040: saving model to Text-Generator.h5
# Epoch 41/150
# 354/354 [==============================] - 13s 35ms/step - loss: 4.1305 - accuracy: 0.1191
#
# Epoch 00041: saving model to Text-Generator.h5
# Epoch 42/150
# 354/354 [==============================] - 12s 33ms/step - loss: 4.1027 - accuracy: 0.1227
#
# Epoch 00042: saving model to Text-Generator.h5
# Epoch 43/150
# 354/354 [==============================] - 9s 26ms/step - loss: 4.0817 - accuracy: 0.1240
#
# Epoch 00043: saving model to Text-Generator.h5
# Epoch 44/150
# 354/354 [==============================] - 9s 25ms/step - loss: 4.0504 - accuracy: 0.1254
#
# Epoch 00044: saving model to Text-Generator.h5
# Epoch 45/150
# 354/354 [==============================] - 9s 25ms/step - loss: 4.0264 - accuracy: 0.1268
#
# Epoch 00045: saving model to Text-Generator.h5
# Epoch 46/150
# 354/354 [==============================] - 9s 24ms/step - loss: 3.9988 - accuracy: 0.1262
#
# Epoch 00046: saving model to Text-Generator.h5
# Epoch 47/150
# 354/354 [==============================] - 9s 24ms/step - loss: 3.9716 - accuracy: 0.1343
#
# Epoch 00047: saving model to Text-Generator.h5
# Epoch 48/150
# 354/354 [==============================] - 9s 24ms/step - loss: 3.9505 - accuracy: 0.1296
#
# Epoch 00048: saving model to Text-Generator.h5
# Epoch 49/150
# 354/354 [==============================] - 9s 25ms/step - loss: 3.9333 - accuracy: 0.1325
#
# Epoch 00049: saving model to Text-Generator.h5
# Epoch 50/150
# 354/354 [==============================] - 9s 26ms/step - loss: 3.8929 - accuracy: 0.1395
#
# Epoch 00050: saving model to Text-Generator.h5
# Epoch 51/150
# 354/354 [==============================] - 9s 25ms/step - loss: 3.8795 - accuracy: 0.1380
#
# Epoch 00051: saving model to Text-Generator.h5
# Epoch 52/150
# 354/354 [==============================] - 9s 25ms/step - loss: 3.8501 - accuracy: 0.1422
#
# Epoch 00052: saving model to Text-Generator.h5
# Epoch 53/150
# 354/354 [==============================] - 9s 25ms/step - loss: 3.8233 - accuracy: 0.1427
#
# Epoch 00053: saving model to Text-Generator.h5
# Epoch 54/150
# 354/354 [==============================] - 9s 25ms/step - loss: 3.8017 - accuracy: 0.1433
#
# Epoch 00054: saving model to Text-Generator.h5
# Epoch 55/150
# 354/354 [==============================] - 9s 25ms/step - loss: 3.7715 - accuracy: 0.1474
#
# Epoch 00055: saving model to Text-Generator.h5
# Epoch 56/150
# 354/354 [==============================] - 9s 26ms/step - loss: 3.7537 - accuracy: 0.1507
#
# Epoch 00056: saving model to Text-Generator.h5
# Epoch 57/150
# 354/354 [==============================] - 9s 27ms/step - loss: 3.7311 - accuracy: 0.1533
#
# Epoch 00057: saving model to Text-Generator.h5
# Epoch 58/150
# 354/354 [==============================] - 9s 26ms/step - loss: 3.7137 - accuracy: 0.1561
#
# Epoch 00058: saving model to Text-Generator.h5
# Epoch 59/150
# 354/354 [==============================] - 9s 25ms/step - loss: 3.6855 - accuracy: 0.1580
#
# Epoch 00059: saving model to Text-Generator.h5
# Epoch 60/150
# 354/354 [==============================] - 9s 25ms/step - loss: 3.6617 - accuracy: 0.1644
#
# Epoch 00060: saving model to Text-Generator.h5
# Epoch 61/150
# 354/354 [==============================] - 9s 26ms/step - loss: 3.6396 - accuracy: 0.1634
#
# Epoch 00061: saving model to Text-Generator.h5
# Epoch 62/150
# 354/354 [==============================] - 15s 43ms/step - loss: 3.6131 - accuracy: 0.1675
#
# Epoch 00062: saving model to Text-Generator.h5
# Epoch 63/150
# 354/354 [==============================] - 16s 44ms/step - loss: 3.6069 - accuracy: 0.1682
#
# Epoch 00063: saving model to Text-Generator.h5
# Epoch 64/150
# 354/354 [==============================] - 15s 42ms/step - loss: 3.5754 - accuracy: 0.1733
#
# Epoch 00064: saving model to Text-Generator.h5
# Epoch 65/150
# 354/354 [==============================] - 13s 37ms/step - loss: 3.5583 - accuracy: 0.1749
#
# Epoch 00065: saving model to Text-Generator.h5
# Epoch 66/150
# 354/354 [==============================] - 13s 36ms/step - loss: 3.5327 - accuracy: 0.1743
#
# Epoch 00066: saving model to Text-Generator.h5
# Epoch 67/150
# 354/354 [==============================] - 13s 38ms/step - loss: 3.5137 - accuracy: 0.1808
#
# Epoch 00067: saving model to Text-Generator.h5
# Epoch 68/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.4947 - accuracy: 0.1831
#
# Epoch 00068: saving model to Text-Generator.h5
# Epoch 69/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.4720 - accuracy: 0.1828
#
# Epoch 00069: saving model to Text-Generator.h5
# Epoch 70/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.4498 - accuracy: 0.1912
#
# Epoch 00070: saving model to Text-Generator.h5
# Epoch 71/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.4356 - accuracy: 0.1902
#
# Epoch 00071: saving model to Text-Generator.h5
# Epoch 72/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.4169 - accuracy: 0.1965
#
# Epoch 00072: saving model to Text-Generator.h5
# Epoch 73/150
# 354/354 [==============================] - 12s 34ms/step - loss: 3.3891 - accuracy: 0.2010
#
# Epoch 00073: saving model to Text-Generator.h5
# Epoch 74/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.3661 - accuracy: 0.2031
#
# Epoch 00074: saving model to Text-Generator.h5
# Epoch 75/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.3517 - accuracy: 0.2079
#
# Epoch 00075: saving model to Text-Generator.h5
# Epoch 76/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.3324 - accuracy: 0.2083
#
# Epoch 00076: saving model to Text-Generator.h5
# Epoch 77/150
# 354/354 [==============================] - 12s 34ms/step - loss: 3.3029 - accuracy: 0.2156
#
# Epoch 00077: saving model to Text-Generator.h5
# Epoch 78/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.2847 - accuracy: 0.2185
#
# Epoch 00078: saving model to Text-Generator.h5
# Epoch 79/150
# 354/354 [==============================] - 12s 34ms/step - loss: 3.2742 - accuracy: 0.2199
#
# Epoch 00079: saving model to Text-Generator.h5
# Epoch 80/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.2555 - accuracy: 0.2243
#
# Epoch 00080: saving model to Text-Generator.h5
# Epoch 81/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.2313 - accuracy: 0.2257
#
# Epoch 00081: saving model to Text-Generator.h5
# Epoch 82/150
# 354/354 [==============================] - 12s 35ms/step - loss: 3.2112 - accuracy: 0.2350
#
# Epoch 00082: saving model to Text-Generator.h5
# Epoch 83/150
# 354/354 [==============================] - 12s 34ms/step - loss: 3.1915 - accuracy: 0.2293
#
# Epoch 00083: saving model to Text-Generator.h5
# Epoch 84/150
# 354/354 [==============================] - 12s 34ms/step - loss: 3.1749 - accuracy: 0.2411
#
# Epoch 00084: saving model to Text-Generator.h5
# Epoch 85/150
# 354/354 [==============================] - 12s 34ms/step - loss: 3.1577 - accuracy: 0.2414
#
# Epoch 00085: saving model to Text-Generator.h5
# Epoch 86/150
# 354/354 [==============================] - 12s 34ms/step - loss: 3.1343 - accuracy: 0.2428
#
# Epoch 00086: saving model to Text-Generator.h5
# Epoch 87/150
# 354/354 [==============================] - 13s 36ms/step - loss: 3.1228 - accuracy: 0.2456
#
# Epoch 00087: saving model to Text-Generator.h5
# Epoch 88/150
# 354/354 [==============================] - 12s 34ms/step - loss: 3.0994 - accuracy: 0.2518
#
# Epoch 00088: saving model to Text-Generator.h5
# Epoch 89/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.0837 - accuracy: 0.2513
#
# Epoch 00089: saving model to Text-Generator.h5
# Epoch 90/150
# 354/354 [==============================] - 13s 35ms/step - loss: 3.0583 - accuracy: 0.2600
#
# Epoch 00090: saving model to Text-Generator.h5
# Epoch 91/150
# 354/354 [==============================] - 12s 35ms/step - loss: 3.0406 - accuracy: 0.2626
#
# Epoch 00091: saving model to Text-Generator.h5
# Epoch 92/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.0195 - accuracy: 0.2673
#
# Epoch 00092: saving model to Text-Generator.h5
# Epoch 93/150
# 354/354 [==============================] - 12s 33ms/step - loss: 3.0082 - accuracy: 0.2697
#
# Epoch 00093: saving model to Text-Generator.h5
# Epoch 94/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.9861 - accuracy: 0.2725
#
# Epoch 00094: saving model to Text-Generator.h5
# Epoch 95/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.9718 - accuracy: 0.2712
#
# Epoch 00095: saving model to Text-Generator.h5
# Epoch 96/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.9410 - accuracy: 0.2817
#
# Epoch 00096: saving model to Text-Generator.h5
# Epoch 97/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.9335 - accuracy: 0.2862
#
# Epoch 00097: saving model to Text-Generator.h5
# Epoch 98/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.9177 - accuracy: 0.2851
#
# Epoch 00098: saving model to Text-Generator.h5
# Epoch 99/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.8879 - accuracy: 0.2943
#
# Epoch 00099: saving model to Text-Generator.h5
# Epoch 100/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.8711 - accuracy: 0.2965
#
# Epoch 00100: saving model to Text-Generator.h5
# Epoch 101/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.8546 - accuracy: 0.2998
#
# Epoch 00101: saving model to Text-Generator.h5
# Epoch 102/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.8402 - accuracy: 0.3021
#
# Epoch 00102: saving model to Text-Generator.h5
# Epoch 103/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.8222 - accuracy: 0.3065
#
# Epoch 00103: saving model to Text-Generator.h5
# Epoch 104/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.7962 - accuracy: 0.3093
#
# Epoch 00104: saving model to Text-Generator.h5
# Epoch 105/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.7731 - accuracy: 0.3121
#
# Epoch 00105: saving model to Text-Generator.h5
# Epoch 106/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.7500 - accuracy: 0.3234
#
# Epoch 00106: saving model to Text-Generator.h5
# Epoch 107/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.7449 - accuracy: 0.3195
#
# Epoch 00107: saving model to Text-Generator.h5
# Epoch 108/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.7343 - accuracy: 0.3210
#
# Epoch 00108: saving model to Text-Generator.h5
# Epoch 109/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.7128 - accuracy: 0.3273
#
# Epoch 00109: saving model to Text-Generator.h5
# Epoch 110/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.7003 - accuracy: 0.3321
#
# Epoch 00110: saving model to Text-Generator.h5
# Epoch 111/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.6706 - accuracy: 0.3327
#
# Epoch 00111: saving model to Text-Generator.h5
# Epoch 112/150
# 354/354 [==============================] - 12s 35ms/step - loss: 2.6400 - accuracy: 0.3454
#
# Epoch 00112: saving model to Text-Generator.h5
# Epoch 113/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.6219 - accuracy: 0.3498
#
# Epoch 00113: saving model to Text-Generator.h5
# Epoch 114/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.6092 - accuracy: 0.3468
#
# Epoch 00114: saving model to Text-Generator.h5
# Epoch 115/150
# 354/354 [==============================] - 12s 35ms/step - loss: 2.5979 - accuracy: 0.3511
#
# Epoch 00115: saving model to Text-Generator.h5
# Epoch 116/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.5889 - accuracy: 0.3518
#
# Epoch 00116: saving model to Text-Generator.h5
# Epoch 117/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.5628 - accuracy: 0.3561
#
# Epoch 00117: saving model to Text-Generator.h5
# Epoch 118/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.5399 - accuracy: 0.3683
#
# Epoch 00118: saving model to Text-Generator.h5
# Epoch 119/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.5242 - accuracy: 0.3641
#
# Epoch 00119: saving model to Text-Generator.h5
# Epoch 120/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.5013 - accuracy: 0.3726
#
# Epoch 00120: saving model to Text-Generator.h5
# Epoch 121/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.4804 - accuracy: 0.3786
#
# Epoch 00121: saving model to Text-Generator.h5
# Epoch 122/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.4760 - accuracy: 0.3751
#
# Epoch 00122: saving model to Text-Generator.h5
# Epoch 123/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.4550 - accuracy: 0.3835
#
# Epoch 00123: saving model to Text-Generator.h5
# Epoch 124/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.4324 - accuracy: 0.3932
#
# Epoch 00124: saving model to Text-Generator.h5
# Epoch 125/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.4150 - accuracy: 0.3927
#
# Epoch 00125: saving model to Text-Generator.h5
# Epoch 126/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.3901 - accuracy: 0.3974
#
# Epoch 00126: saving model to Text-Generator.h5
# Epoch 127/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.3835 - accuracy: 0.3955
#
# Epoch 00127: saving model to Text-Generator.h5
# Epoch 128/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.3592 - accuracy: 0.4042
#
# Epoch 00128: saving model to Text-Generator.h5
# Epoch 129/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.3408 - accuracy: 0.4061
#
# Epoch 00129: saving model to Text-Generator.h5
# Epoch 130/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.3218 - accuracy: 0.4126
#
# Epoch 00130: saving model to Text-Generator.h5
# Epoch 131/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.3086 - accuracy: 0.4158
#
# Epoch 00131: saving model to Text-Generator.h5
# Epoch 132/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.2956 - accuracy: 0.4159
#
# Epoch 00132: saving model to Text-Generator.h5
# Epoch 133/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.2789 - accuracy: 0.4205
#
# Epoch 00133: saving model to Text-Generator.h5
# Epoch 134/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.2674 - accuracy: 0.4261
#
# Epoch 00134: saving model to Text-Generator.h5
# Epoch 135/150
# 354/354 [==============================] - 12s 33ms/step - loss: 2.2386 - accuracy: 0.4355
#
# Epoch 00135: saving model to Text-Generator.h5
# Epoch 136/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.2188 - accuracy: 0.4377
#
# Epoch 00136: saving model to Text-Generator.h5
# Epoch 137/150
# 354/354 [==============================] - 12s 35ms/step - loss: 2.2231 - accuracy: 0.4353
#
# Epoch 00137: saving model to Text-Generator.h5
# Epoch 138/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.1818 - accuracy: 0.4461
#
# Epoch 00138: saving model to Text-Generator.h5
# Epoch 139/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.1630 - accuracy: 0.4505
#
# Epoch 00139: saving model to Text-Generator.h5
# Epoch 140/150
# 354/354 [==============================] - 13s 37ms/step - loss: 2.1606 - accuracy: 0.4491
#
# Epoch 00140: saving model to Text-Generator.h5
# Epoch 141/150
# 354/354 [==============================] - 12s 35ms/step - loss: 2.1320 - accuracy: 0.4506
#
# Epoch 00141: saving model to Text-Generator.h5
# Epoch 142/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.1265 - accuracy: 0.4536
#
# Epoch 00142: saving model to Text-Generator.h5
# Epoch 143/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.1019 - accuracy: 0.4612
#
# Epoch 00143: saving model to Text-Generator.h5
# Epoch 144/150
# 354/354 [==============================] - 12s 35ms/step - loss: 2.0869 - accuracy: 0.4650
#
# Epoch 00144: saving model to Text-Generator.h5
# Epoch 145/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.0887 - accuracy: 0.4659
#
# Epoch 00145: saving model to Text-Generator.h5
# Epoch 146/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.0666 - accuracy: 0.4731
#
# Epoch 00146: saving model to Text-Generator.h5
# Epoch 147/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.0533 - accuracy: 0.4723
#
# Epoch 00147: saving model to Text-Generator.h5
# Epoch 148/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.0299 - accuracy: 0.4774
#
# Epoch 00148: saving model to Text-Generator.h5
# Epoch 149/150
# 354/354 [==============================] - 12s 34ms/step - loss: 2.0065 - accuracy: 0.4891
#
# Epoch 00149: saving model to Text-Generator.h5
# Epoch 150/150
# 354/354 [==============================] - 12s 34ms/step - loss: 1.9954 - accuracy: 0.4924
#
# Epoch 00150: saving model to Text-Generator.h5

# %%
from pickle import load, dump

# %%
# Saving the Text Tokenizer
dump(text_tokenizer, open("LSTM_Tokenizer", "wb"))

# %%
features[0].shape
# Out:
# (14,)

# %%
# Reshaping the Input Text to get the words as a string!
model.predict(features[0].reshape(1, -1))
# Out:
# array([[4.7728451e-19, 4.4772471e-04, 1.5792391e-05, ..., 6.2675482e-25,
#         1.2826639e-35, 0.0000000e+00]], dtype=float32)

# %%
# Printing the shape of the prediction
model.predict(features[0].reshape(1, -1)).shape
# Out:
# (1, 2719)

# %%
# Getting the word index that comes after the sequence that we have passed
model.predict(features[0].reshape(1, -1)).argmax(axis = 1)[0]
# Out:
# 97

# %%
# Printing the actual word
text_tokenizer.index_word[97]
# Out:
# 'are'

# %%
# Getting the Final Word from the Original Sequences & comparing it with the predicted one!
index = 1
word_index = model.predict(features[index].reshape(1, -1)).argmax(axis = 1)[0]
print(word_index, text_tokenizer.index_word[word_index])
print(final_sequences[index][-1])
# Out:
# 263 money
# 263

# %%
text_tokenizer.texts_to_sequences("I am Pro, I am an Indian, My Name is Harshit Dawar")
# Out:
# [[5],
#  [],
#  [2],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [5],
#  [],
#  [2],
#  [],
#  [],
#  [2],
#  [],
#  [],
#  [5],
#  [],
#  [],
#  [5],
#  [2],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [2],
#  [],
#  [404],
#  [],
#  [5],
#  [],
#  [],
#  [],
#  [2],
#  [],
#  [],
#  [],
#  [5],
#  [],
#  [],
#  [],
#  [2],
#  [],
#  [2],
#  []]

# %%
# Importing to pad the sequences
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
def text_generator(model, tokenizer, num_words_to_gen, text_sequence, sequence_length):
    predicted_words = []
    
    input_seq = text_sequence
    
    for word_index in range(num_words_to_gen):
        # Passing in 2D array as below is very important for the right working!
        encoded_sequence = tokenizer.texts_to_sequences([input_seq])[0]
        
        # Pre Truncate will chop off the initial word from the sentence!
        padded_sequence = pad_sequences([encoded_sequence], maxlen = sequence_length, truncating = "pre")
    
        gen_word_index = model.predict(padded_sequence).argmax(axis = 1)[0]
        
        gen_word = tokenizer.index_word[gen_word_index]
        
        input_seq += " " + gen_word
        
        predicted_words.append(gen_word)
        
    return " ".join(predicted_words)

# %%
text_generator(model, text_tokenizer, 9, "I am Harshit Dawar, I am Indian, I am the best, everyone knows this", 14)
# Out:
# 'sooty shouted the battery and a sunset and a'

# %%
text_generator(model, text_tokenizer, 15, " ".join(sequences[1155][:-1]), 14)
# Out:
# 'cook being deeply brown and save me on i struck one in a passion though'

# %%
sequences[1155][:-1]
# Out:
# ['as',
#  'for',
#  'going',
#  'as',
#  'cook,--though',
#  'i',
#  'confess',
#  'there',
#  'is',
#  'considerable',
#  'glory',
#  'in',
#  'that',
#  'a']

# %%
" ".join(sequences[1155][:-1])
# Out:
# 'as for going as cook,--though i confess there is considerable glory in that a'

# %%
text_tokenizer.texts_to_sequences([" ".join(sequences[1155][:-1])])
# Out:
# [[16, 22, 154, 16, 614, 79, 5, 617, 29, 20, 1183, 615, 7, 9, 2]]

# %% [markdown]
# ## Generating RNN Model

# %%
from tensorflow.keras.layers import SimpleRNN

# %%
model_RNN = Sequential([
                        Embedding(input_dim = corpus_size + 1,
                                  output_dim = sequence_length,
                                  input_length = sequence_length),
    
     # return_sequences = True is required only for the first time because without it,
     # only number of neurons will be returned."""
                        SimpleRNN(units = 95, return_sequences = True),
    
                        SimpleRNN(units = 95),
                        
                        Dense(units = 100, activation = "relu"),
                        
                        Dense(units = corpus_size + 1, activation = "softmax")
])

model_RNN.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
model_RNN.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 14, 14)            38066
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 14, 95)            10450
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 95)                18145
# _________________________________________________________________
# dense_18 (Dense)             (None, 100)               9600
# _________________________________________________________________
# dense_19 (Dense)             (None, 2719)              274619
# =================================================================
# Total params: 350,880
# Trainable params: 350,880
# Non-trainable params: 0
# _________________________________________________________________

# %%
MC = ModelCheckpoint(filepath = "Text-Generator-RNN.h5", monitor = "loss", verbose = 1)
history_RNN = model_RNN.fit(features, labels, epochs = 150, verbose = 1, callbacks = [MC])
# Out:
# Epoch 1/150
# 354/354 [==============================] - 7s 16ms/step - loss: 6.6756 - accuracy: 0.0500
#
# Epoch 00001: saving model to Text-Generator-RNN.h5
# Epoch 2/150
# 354/354 [==============================] - 7s 19ms/step - loss: 6.4114 - accuracy: 0.0519
#
# Epoch 00002: saving model to Text-Generator-RNN.h5
# Epoch 3/150
# 354/354 [==============================] - 7s 19ms/step - loss: 6.3484 - accuracy: 0.0529
#
# Epoch 00003: saving model to Text-Generator-RNN.h5
# Epoch 4/150
# 354/354 [==============================] - 7s 19ms/step - loss: 6.3350 - accuracy: 0.0529
#
# Epoch 00004: saving model to Text-Generator-RNN.h5
# Epoch 5/150
# 354/354 [==============================] - 5s 15ms/step - loss: 6.3318 - accuracy: 0.0529
#
# Epoch 00005: saving model to Text-Generator-RNN.h5
# Epoch 6/150
# 354/354 [==============================] - 6s 17ms/step - loss: 6.3316 - accuracy: 0.0529
#
# Epoch 00006: saving model to Text-Generator-RNN.h5
# Epoch 7/150
# 354/354 [==============================] - 5s 15ms/step - loss: 6.3200 - accuracy: 0.0526
#
# Epoch 00007: saving model to Text-Generator-RNN.h5
# Epoch 8/150
# 354/354 [==============================] - 5s 15ms/step - loss: 6.2047 - accuracy: 0.0529
#
# Epoch 00008: saving model to Text-Generator-RNN.h5
# Epoch 9/150
# 354/354 [==============================] - 5s 15ms/step - loss: 6.1259 - accuracy: 0.0529
#
# Epoch 00009: saving model to Text-Generator-RNN.h5
# Epoch 10/150
# 354/354 [==============================] - 5s 15ms/step - loss: 6.0510 - accuracy: 0.0529
#
# Epoch 00010: saving model to Text-Generator-RNN.h5
# Epoch 11/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.9526 - accuracy: 0.0613
#
# Epoch 00011: saving model to Text-Generator-RNN.h5
# Epoch 12/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.8554 - accuracy: 0.0660
#
# Epoch 00012: saving model to Text-Generator-RNN.h5
# Epoch 13/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.7754 - accuracy: 0.0686
#
# Epoch 00013: saving model to Text-Generator-RNN.h5
# Epoch 14/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.6941 - accuracy: 0.0692
#
# Epoch 00014: saving model to Text-Generator-RNN.h5
# Epoch 15/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.6184 - accuracy: 0.0717
#
# Epoch 00015: saving model to Text-Generator-RNN.h5
# Epoch 16/150
# 354/354 [==============================] - 6s 16ms/step - loss: 5.5700 - accuracy: 0.0729
#
# Epoch 00016: saving model to Text-Generator-RNN.h5
# Epoch 17/150
# 354/354 [==============================] - 6s 16ms/step - loss: 5.5085 - accuracy: 0.0762
#
# Epoch 00017: saving model to Text-Generator-RNN.h5
# Epoch 18/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.4448 - accuracy: 0.0770
#
# Epoch 00018: saving model to Text-Generator-RNN.h5
# Epoch 19/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.3920 - accuracy: 0.0778
#
# Epoch 00019: saving model to Text-Generator-RNN.h5
# Epoch 20/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.3469 - accuracy: 0.0799
#
# Epoch 00020: saving model to Text-Generator-RNN.h5
# Epoch 21/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.3031 - accuracy: 0.0808
#
# Epoch 00021: saving model to Text-Generator-RNN.h5
# Epoch 22/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.2592 - accuracy: 0.0819
#
# Epoch 00022: saving model to Text-Generator-RNN.h5
# Epoch 23/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.2387 - accuracy: 0.0834
#
# Epoch 00023: saving model to Text-Generator-RNN.h5
# Epoch 24/150
# 354/354 [==============================] - 5s 15ms/step - loss: 5.1845 - accuracy: 0.0870
#
# Epoch 00024: saving model to Text-Generator-RNN.h5
# Epoch 25/150
# 354/354 [==============================] - 6s 18ms/step - loss: 5.2158 - accuracy: 0.0849
#
# Epoch 00025: saving model to Text-Generator-RNN.h5
# Epoch 26/150
# 354/354 [==============================] - 6s 16ms/step - loss: 5.1939 - accuracy: 0.0870
#
# Epoch 00026: saving model to Text-Generator-RNN.h5
# Epoch 27/150
# 354/354 [==============================] - 7s 19ms/step - loss: 5.1173 - accuracy: 0.0897
#
# Epoch 00027: saving model to Text-Generator-RNN.h5
# Epoch 28/150
# 354/354 [==============================] - 5s 14ms/step - loss: 5.0620 - accuracy: 0.0919
#
# Epoch 00028: saving model to Text-Generator-RNN.h5
# Epoch 29/150
# 354/354 [==============================] - 4s 13ms/step - loss: 5.0219 - accuracy: 0.0958
#
# Epoch 00029: saving model to Text-Generator-RNN.h5
# Epoch 30/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.9875 - accuracy: 0.0951
#
# Epoch 00030: saving model to Text-Generator-RNN.h5
# Epoch 31/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.9494 - accuracy: 0.0971
#
# Epoch 00031: saving model to Text-Generator-RNN.h5
# Epoch 32/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.9060 - accuracy: 0.1012
#
# Epoch 00032: saving model to Text-Generator-RNN.h5
# Epoch 33/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.8624 - accuracy: 0.1047
#
# Epoch 00033: saving model to Text-Generator-RNN.h5
# Epoch 34/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.8124 - accuracy: 0.1093
#
# Epoch 00034: saving model to Text-Generator-RNN.h5
# Epoch 35/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.7601 - accuracy: 0.1143
#
# Epoch 00035: saving model to Text-Generator-RNN.h5
# Epoch 36/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.7130 - accuracy: 0.1178
#
# Epoch 00036: saving model to Text-Generator-RNN.h5
# Epoch 37/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.6680 - accuracy: 0.1213
#
# Epoch 00037: saving model to Text-Generator-RNN.h5
# Epoch 38/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.6181 - accuracy: 0.1233
#
# Epoch 00038: saving model to Text-Generator-RNN.h5
# Epoch 39/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.5720 - accuracy: 0.1248
#
# Epoch 00039: saving model to Text-Generator-RNN.h5
# Epoch 40/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.5211 - accuracy: 0.1328
#
# Epoch 00040: saving model to Text-Generator-RNN.h5
# Epoch 41/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.4889 - accuracy: 0.1368
#
# Epoch 00041: saving model to Text-Generator-RNN.h5
# Epoch 42/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.4437 - accuracy: 0.1366
#
# Epoch 00042: saving model to Text-Generator-RNN.h5
# Epoch 43/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.3875 - accuracy: 0.1413
#
# Epoch 00043: saving model to Text-Generator-RNN.h5
# Epoch 44/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.3515 - accuracy: 0.1449
#
# Epoch 00044: saving model to Text-Generator-RNN.h5
# Epoch 45/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.4985 - accuracy: 0.1361
#
# Epoch 00045: saving model to Text-Generator-RNN.h5
# Epoch 46/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.4032 - accuracy: 0.1386
#
# Epoch 00046: saving model to Text-Generator-RNN.h5
# Epoch 47/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.3130 - accuracy: 0.1436
#
# Epoch 00047: saving model to Text-Generator-RNN.h5
# Epoch 48/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.2130 - accuracy: 0.1535
#
# Epoch 00048: saving model to Text-Generator-RNN.h5
# Epoch 49/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.1536 - accuracy: 0.1597
#
# Epoch 00049: saving model to Text-Generator-RNN.h5
# Epoch 50/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.1158 - accuracy: 0.1635
#
# Epoch 00050: saving model to Text-Generator-RNN.h5
# Epoch 51/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.0803 - accuracy: 0.1664
#
# Epoch 00051: saving model to Text-Generator-RNN.h5
# Epoch 52/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.0298 - accuracy: 0.1711
#
# Epoch 00052: saving model to Text-Generator-RNN.h5
# Epoch 53/150
# 354/354 [==============================] - 4s 12ms/step - loss: 4.0046 - accuracy: 0.1710
#
# Epoch 00053: saving model to Text-Generator-RNN.h5
# Epoch 54/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.9607 - accuracy: 0.1749
#
# Epoch 00054: saving model to Text-Generator-RNN.h5
# Epoch 55/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.9285 - accuracy: 0.1799
#
# Epoch 00055: saving model to Text-Generator-RNN.h5
# Epoch 56/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.8917 - accuracy: 0.1863
#
# Epoch 00056: saving model to Text-Generator-RNN.h5
# Epoch 57/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.8667 - accuracy: 0.1819
#
# Epoch 00057: saving model to Text-Generator-RNN.h5
# Epoch 58/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.8131 - accuracy: 0.1912
#
# Epoch 00058: saving model to Text-Generator-RNN.h5
# Epoch 59/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.7893 - accuracy: 0.1911
#
# Epoch 00059: saving model to Text-Generator-RNN.h5
# Epoch 60/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.7392 - accuracy: 0.1999
#
# Epoch 00060: saving model to Text-Generator-RNN.h5
# Epoch 61/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.7063 - accuracy: 0.2018
#
# Epoch 00061: saving model to Text-Generator-RNN.h5
# Epoch 62/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.6754 - accuracy: 0.2083
#
# Epoch 00062: saving model to Text-Generator-RNN.h5
# Epoch 63/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.6464 - accuracy: 0.2053
#
# Epoch 00063: saving model to Text-Generator-RNN.h5
# Epoch 64/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.6013 - accuracy: 0.2159
#
# Epoch 00064: saving model to Text-Generator-RNN.h5
# Epoch 65/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.5752 - accuracy: 0.2169
#
# Epoch 00065: saving model to Text-Generator-RNN.h5
# Epoch 66/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.5359 - accuracy: 0.2235
#
# Epoch 00066: saving model to Text-Generator-RNN.h5
# Epoch 67/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.5113 - accuracy: 0.2293
#
# Epoch 00067: saving model to Text-Generator-RNN.h5
# Epoch 68/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.4720 - accuracy: 0.2329
#
# Epoch 00068: saving model to Text-Generator-RNN.h5
# Epoch 69/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.4522 - accuracy: 0.2336
#
# Epoch 00069: saving model to Text-Generator-RNN.h5
# Epoch 70/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.4411 - accuracy: 0.2370
#
# Epoch 00070: saving model to Text-Generator-RNN.h5
# Epoch 71/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.3895 - accuracy: 0.2402
#
# Epoch 00071: saving model to Text-Generator-RNN.h5
# Epoch 72/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.8290 - accuracy: 0.2003
#
# Epoch 00072: saving model to Text-Generator-RNN.h5
# Epoch 73/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.7418 - accuracy: 0.2093
#
# Epoch 00073: saving model to Text-Generator-RNN.h5
# Epoch 74/150
# 354/354 [==============================] - 4s 11ms/step - loss: 3.5629 - accuracy: 0.2223
#
# Epoch 00074: saving model to Text-Generator-RNN.h5
# Epoch 75/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.4060 - accuracy: 0.2403
#
# Epoch 00075: saving model to Text-Generator-RNN.h5
# Epoch 76/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.4453 - accuracy: 0.2327
#
# Epoch 00076: saving model to Text-Generator-RNN.h5
# Epoch 77/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.3218 - accuracy: 0.2504
#
# Epoch 00077: saving model to Text-Generator-RNN.h5
# Epoch 78/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.3873 - accuracy: 0.2518
#
# Epoch 00078: saving model to Text-Generator-RNN.h5
# Epoch 79/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.5385 - accuracy: 0.2288
#
# Epoch 00079: saving model to Text-Generator-RNN.h5
# Epoch 80/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.3383 - accuracy: 0.2466
#
# Epoch 00080: saving model to Text-Generator-RNN.h5
# Epoch 81/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.3862 - accuracy: 0.2452
#
# Epoch 00081: saving model to Text-Generator-RNN.h5
# Epoch 82/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.5160 - accuracy: 0.2334
#
# Epoch 00082: saving model to Text-Generator-RNN.h5
# Epoch 83/150
# 354/354 [==============================] - 5s 14ms/step - loss: 3.6115 - accuracy: 0.2172
#
# Epoch 00083: saving model to Text-Generator-RNN.h5
# Epoch 84/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.2239 - accuracy: 0.2616
#
# Epoch 00084: saving model to Text-Generator-RNN.h5
# Epoch 85/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.1156 - accuracy: 0.2795
#
# Epoch 00085: saving model to Text-Generator-RNN.h5
# Epoch 86/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.0414 - accuracy: 0.2941
#
# Epoch 00086: saving model to Text-Generator-RNN.h5
# Epoch 87/150
# 354/354 [==============================] - 4s 12ms/step - loss: 3.0132 - accuracy: 0.2982
#
# Epoch 00087: saving model to Text-Generator-RNN.h5
# Epoch 88/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.9929 - accuracy: 0.2991
#
# Epoch 00088: saving model to Text-Generator-RNN.h5
# Epoch 89/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.9689 - accuracy: 0.3035
#
# Epoch 00089: saving model to Text-Generator-RNN.h5
# Epoch 90/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.9302 - accuracy: 0.3119
#
# Epoch 00090: saving model to Text-Generator-RNN.h5
# Epoch 91/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.9182 - accuracy: 0.3081
#
# Epoch 00091: saving model to Text-Generator-RNN.h5
# Epoch 92/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.9080 - accuracy: 0.3174
#
# Epoch 00092: saving model to Text-Generator-RNN.h5
# Epoch 93/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.8768 - accuracy: 0.3168
#
# Epoch 00093: saving model to Text-Generator-RNN.h5
# Epoch 94/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.8544 - accuracy: 0.3230
#
# Epoch 00094: saving model to Text-Generator-RNN.h5
# Epoch 95/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.8223 - accuracy: 0.3291
#
# Epoch 00095: saving model to Text-Generator-RNN.h5
# Epoch 96/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.8733 - accuracy: 0.3212
#
# Epoch 00096: saving model to Text-Generator-RNN.h5
# Epoch 97/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.7997 - accuracy: 0.3303
#
# Epoch 00097: saving model to Text-Generator-RNN.h5
# Epoch 98/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.7477 - accuracy: 0.3491
#
# Epoch 00098: saving model to Text-Generator-RNN.h5
# Epoch 99/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.7038 - accuracy: 0.3496
#
# Epoch 00099: saving model to Text-Generator-RNN.h5
# Epoch 100/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.7010 - accuracy: 0.3497
#
# Epoch 00100: saving model to Text-Generator-RNN.h5
# Epoch 101/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.6799 - accuracy: 0.3529
#
# Epoch 00101: saving model to Text-Generator-RNN.h5
# Epoch 102/150
# 354/354 [==============================] - 4s 11ms/step - loss: 2.6529 - accuracy: 0.3559
#
# Epoch 00102: saving model to Text-Generator-RNN.h5
# Epoch 103/150
# 354/354 [==============================] - 4s 10ms/step - loss: 2.6488 - accuracy: 0.3609
#
# Epoch 00103: saving model to Text-Generator-RNN.h5
# Epoch 104/150
# 354/354 [==============================] - 4s 10ms/step - loss: 2.6172 - accuracy: 0.3682
#
# Epoch 00104: saving model to Text-Generator-RNN.h5
# Epoch 105/150
# 354/354 [==============================] - 4s 13ms/step - loss: 2.5717 - accuracy: 0.3739
#
# Epoch 00105: saving model to Text-Generator-RNN.h5
# Epoch 106/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.5431 - accuracy: 0.3794
#
# Epoch 00106: saving model to Text-Generator-RNN.h5
# Epoch 107/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.5255 - accuracy: 0.3806
#
# Epoch 00107: saving model to Text-Generator-RNN.h5
# Epoch 108/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.5571 - accuracy: 0.3804
#
# Epoch 00108: saving model to Text-Generator-RNN.h5
# Epoch 109/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.4939 - accuracy: 0.3918
#
# Epoch 00109: saving model to Text-Generator-RNN.h5
# Epoch 110/150
# 354/354 [==============================] - 5s 13ms/step - loss: 2.4476 - accuracy: 0.3984
#
# Epoch 00110: saving model to Text-Generator-RNN.h5
# Epoch 111/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.4657 - accuracy: 0.3919
#
# Epoch 00111: saving model to Text-Generator-RNN.h5
# Epoch 112/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.3945 - accuracy: 0.4101
#
# Epoch 00112: saving model to Text-Generator-RNN.h5
# Epoch 113/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.3629 - accuracy: 0.4154
#
# Epoch 00113: saving model to Text-Generator-RNN.h5
# Epoch 114/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.3480 - accuracy: 0.4239
#
# Epoch 00114: saving model to Text-Generator-RNN.h5
# Epoch 115/150
# 354/354 [==============================] - 4s 11ms/step - loss: 2.3465 - accuracy: 0.4223
#
# Epoch 00115: saving model to Text-Generator-RNN.h5
# Epoch 116/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.3508 - accuracy: 0.4185
#
# Epoch 00116: saving model to Text-Generator-RNN.h5
# Epoch 117/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.3079 - accuracy: 0.4239
#
# Epoch 00117: saving model to Text-Generator-RNN.h5
# Epoch 118/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.3007 - accuracy: 0.4283
#
# Epoch 00118: saving model to Text-Generator-RNN.h5
# Epoch 119/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.2876 - accuracy: 0.4273
#
# Epoch 00119: saving model to Text-Generator-RNN.h5
# Epoch 120/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.2432 - accuracy: 0.4398
#
# Epoch 00120: saving model to Text-Generator-RNN.h5
# Epoch 121/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.2577 - accuracy: 0.4358
#
# Epoch 00121: saving model to Text-Generator-RNN.h5
# Epoch 122/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.2245 - accuracy: 0.4396
#
# Epoch 00122: saving model to Text-Generator-RNN.h5
# Epoch 123/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.1871 - accuracy: 0.4525
#
# Epoch 00123: saving model to Text-Generator-RNN.h5
# Epoch 124/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.1656 - accuracy: 0.4544
#
# Epoch 00124: saving model to Text-Generator-RNN.h5
# Epoch 125/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.1281 - accuracy: 0.4654
#
# Epoch 00125: saving model to Text-Generator-RNN.h5
# Epoch 126/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.1480 - accuracy: 0.4620
#
# Epoch 00126: saving model to Text-Generator-RNN.h5
# Epoch 127/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.1304 - accuracy: 0.4616
#
# Epoch 00127: saving model to Text-Generator-RNN.h5
# Epoch 128/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.0950 - accuracy: 0.4726
#
# Epoch 00128: saving model to Text-Generator-RNN.h5
# Epoch 129/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.0725 - accuracy: 0.4735
#
# Epoch 00129: saving model to Text-Generator-RNN.h5
# Epoch 130/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.0914 - accuracy: 0.4736
#
# Epoch 00130: saving model to Text-Generator-RNN.h5
# Epoch 131/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.0522 - accuracy: 0.4753
#
# Epoch 00131: saving model to Text-Generator-RNN.h5
# Epoch 132/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.0285 - accuracy: 0.4871
#
# Epoch 00132: saving model to Text-Generator-RNN.h5
# Epoch 133/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.0008 - accuracy: 0.4874
#
# Epoch 00133: saving model to Text-Generator-RNN.h5
# Epoch 134/150
# 354/354 [==============================] - 5s 13ms/step - loss: 1.9911 - accuracy: 0.4956
#
# Epoch 00134: saving model to Text-Generator-RNN.h5
# Epoch 135/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.0378 - accuracy: 0.4817
#
# Epoch 00135: saving model to Text-Generator-RNN.h5
# Epoch 136/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.9792 - accuracy: 0.4940
#
# Epoch 00136: saving model to Text-Generator-RNN.h5
# Epoch 137/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.9183 - accuracy: 0.5079
#
# Epoch 00137: saving model to Text-Generator-RNN.h5
# Epoch 138/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.9709 - accuracy: 0.5034
#
# Epoch 00138: saving model to Text-Generator-RNN.h5
# Epoch 139/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.5479 - accuracy: 0.4351
#
# Epoch 00139: saving model to Text-Generator-RNN.h5
# Epoch 140/150
# 354/354 [==============================] - 4s 12ms/step - loss: 2.5283 - accuracy: 0.3926
#
# Epoch 00140: saving model to Text-Generator-RNN.h5
# Epoch 141/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.9992 - accuracy: 0.4870
#
# Epoch 00141: saving model to Text-Generator-RNN.h5
# Epoch 142/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.8561 - accuracy: 0.5249
#
# Epoch 00142: saving model to Text-Generator-RNN.h5
# Epoch 143/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.7869 - accuracy: 0.5415
#
# Epoch 00143: saving model to Text-Generator-RNN.h5
# Epoch 144/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.7908 - accuracy: 0.5378
#
# Epoch 00144: saving model to Text-Generator-RNN.h5
# Epoch 145/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.8102 - accuracy: 0.5332
#
# Epoch 00145: saving model to Text-Generator-RNN.h5
# Epoch 146/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.8216 - accuracy: 0.5320
#
# Epoch 00146: saving model to Text-Generator-RNN.h5
# Epoch 147/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.7969 - accuracy: 0.5403
#
# Epoch 00147: saving model to Text-Generator-RNN.h5
# Epoch 148/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.8367 - accuracy: 0.5274
#
# Epoch 00148: saving model to Text-Generator-RNN.h5
# Epoch 149/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.8089 - accuracy: 0.5343
#
# Epoch 00149: saving model to Text-Generator-RNN.h5
# Epoch 150/150
# 354/354 [==============================] - 4s 12ms/step - loss: 1.7723 - accuracy: 0.5390
#
# Epoch 00150: saving model to Text-Generator-RNN.h5
